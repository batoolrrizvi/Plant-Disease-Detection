# %% [markdown]
# #                                                   PLANT DISEASE DETECTION

# %% [markdown]
# # Step 01
# Covert the images to png to get the cropped image of the leaf

# %%
import os
import cv2
import numpy as np

# ─── CONFIGURATION ────────────────────────────────────────────────────────────
INPUT_ROOT  = 'original_dataset'   # top‐level folder with class subfolders
OUTPUT_ROOT = 'Leaf_Crops_original'         # will get subfolders per class
HSV_LOWER   = np.array([25,  40, 40])
HSV_UPPER   = np.array([85, 255,255])
KERNEL      = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7,7))

def makedirs(path):
    os.makedirs(path, exist_ok=True)

# ensure top‐level output folder exists
makedirs(OUTPUT_ROOT)

# loop over each class subfolder
for class_name in os.listdir(INPUT_ROOT):
    class_in  = os.path.join(INPUT_ROOT,  class_name)
    class_out = os.path.join(OUTPUT_ROOT, class_name)
    if not os.path.isdir(class_in):
        continue
    makedirs(class_out)

    # process each image in that class
    for fname in os.listdir(class_in):
        if not fname.lower().endswith(('.jpg','jpeg','png')):
            continue

        img_path = os.path.join(class_in, fname)
        img      = cv2.imread(img_path)
        if img is None:
            continue

        # 1) Build green‐leaf mask
        hsv  = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        mask = cv2.inRange(hsv, HSV_LOWER, HSV_UPPER)
        mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, KERNEL)
        mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN,  KERNEL)

        # 2) Find the largest contour = leaf
        cnts, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if not cnts:
            print(f"No leaf found in {fname}, skipping.")
            continue
        leaf_cnt = max(cnts, key=cv2.contourArea)

        # 3) Convex hull for smooth boundary
        hull = cv2.convexHull(leaf_cnt)

        # 4) Rasterize hull to alpha mask + bbox
        hull_mask = np.zeros_like(mask)
        cv2.drawContours(hull_mask, [hull], -1, 255, -1)
        ys, xs    = np.where(hull_mask > 0)
        y1, y2    = ys.min(), ys.max()
        x1, x2    = xs.min(), xs.max()

        # 5) Crop BGR + alpha to bbox
        crop_bgr   = img[y1:y2+1, x1:x2+1]
        crop_alpha = hull_mask[y1:y2+1, x1:x2+1]
        b, g, r    = cv2.split(crop_bgr)
        rgba       = cv2.merge([b, g, r, crop_alpha])

        # 6) Save PNG in the proper class folder
        base     = os.path.splitext(fname)[0]
        out_path = os.path.join(class_out, f"{base}_leaf.png")
        cv2.imwrite(out_path, rgba)
        print(f"Saved crop: {out_path}")

print("All done! Cropped leaves in:", OUTPUT_ROOT)

# %% [markdown]
# # Step 02
# It walks through each folder of images and counts the number of images, verifies their format and sizes. It then saves this information in a CSV file image_index.

# %%
import os
import pandas as pd
from PIL import Image

# ─── assuming you run this script from DIP_PROJECT ─────────────────────────────
base_dir = os.path.join(os.getcwd(), "Leaf_Crops_original")
# or whatever your top‐level folder is

records = []
for class_name in os.listdir(base_dir):
    class_folder = os.path.join(base_dir, class_name)
    if not os.path.isdir(class_folder):
        continue

    # look for any common image extension
    img_files = [f for f in os.listdir(class_folder)
                 if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    print(f"Found {len(img_files):2d} images in '{class_name}'")

    for fname in img_files:
        path = os.path.join(class_folder, fname)
        try:
            with Image.open(path) as img:
                w, h = img.size
                fmt = img.format
        except Exception as e:
            print(f"  ✗ Couldn’t open {fname}: {e}")
            continue

        records.append({
            'filepath': path,
            'label':    class_name,
            'format':   fmt,
            'width':    w,
            'height':   h
        })

df = pd.DataFrame(records, columns=['filepath','label','format','width','height'])

print("\nSample rows:")
print(df.sample(5))
print("\nCounts per class:")
print(df['label'].value_counts())

df.to_csv('image_index.csv', index=False)
print("\nWrote image_index.csv")
# Out:
# Found 997 images in 'Pepper__bell___Bacterial_spot'
# Found 1478 images in 'Pepper__bell___healthy'
# Found 1000 images in 'Potato___Early_blight'
# Found 152 images in 'Potato___healthy'
# Found 1000 images in 'Potato___Late_blight'
# Found 2127 images in 'Tomato_Bacterial_spot'
# Found 425 images in 'Tomato_Early_blight'
#
# Sample rows:
#                                                filepath  \
# 6961  c:\Users\hp\Downloads\DIP_PROJECT\Leaf_Crops_o...
# 94    c:\Users\hp\Downloads\DIP_PROJECT\Leaf_Crops_o...
# 4677  c:\Users\hp\Downloads\DIP_PROJECT\Leaf_Crops_o...
# 6798  c:\Users\hp\Downloads\DIP_PROJECT\Leaf_Crops_o...
# 6436  c:\Users\hp\Downloads\DIP_PROJECT\Leaf_Crops_o...
#
#                               label format  width  height
# 6961            Tomato_Early_blight    PNG    156     204
# 94    Pepper__bell___Bacterial_spot    PNG    226     245
# 4677          Tomato_Bacterial_spot    PNG    140     206
# 6798            Tomato_Early_blight    PNG    188     218
# 6436          Tomato_Bacterial_spot    PNG    165     235
#
# Counts per class:
# label
# Tomato_Bacterial_spot            2127
# Pepper__bell___healthy           1478
# Potato___Early_blight            1000
# Potato___Late_blight             1000
# Pepper__bell___Bacterial_spot     997
# Tomato_Early_blight               425
# Potato___healthy                  152
# Name: count, dtype: int64
#
# Wrote image_index.csv

# %% [markdown]
# # Step 03: Data Preprocessing
# The dataset is divided in to train, val and split with a ratio of 70%, 15% and 15% respectively.
#
# 1. **Configure** parameters: set `TARGET_SIZE`, `INDEX_CSV`, `OUTPUT_DIR`, `SPLIT_RATIOS`, and `RANDOM_STATE`.
# 2. **Load** your image index CSV (with columns `filepath,label,format,width,height`) into a DataFrame.
# 3. **Split** the DataFrame into train, validation, and test sets via `train_test_split`, stratified by `label`.
# 4. **Process & save** each split:
#    - Read each image from `filepath`, resize to `TARGET_SIZE`,
#    - Write the resized BGR image to `Processed/<split>/<label>/<filename>`.
# 5. **Log & finish**: print progress for each split, then confirm completion.

# %%
import os
import cv2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# ─── PARAMETERS ────────────────────────────────────────────────────────────────
TARGET_SIZE   = (256, 256)
INDEX_CSV     = "image_index.csv"      # produced earlier
OUTPUT_DIR    = "Processed"
SPLIT_RATIOS  = (0.70, 0.15, 0.15)     # train / val / test
RANDOM_STATE  = 42

# ─── UTILITY: make sure directory exists ───────────────────────────────────────
def makedirs(path):
    os.makedirs(path, exist_ok=True)

# ─── STEP 1: load index CSV ────────────────────────────────────────────────────
df = pd.read_csv(INDEX_CSV)  # columns: filepath,label,format,width,height

# ─── STEP 2: train/val/test split ───────────────────────────────────────────────
train_df, temp_df = train_test_split(
    df,
    test_size=1 - SPLIT_RATIOS[0],
    stratify=df['label'],
    random_state=RANDOM_STATE
)
val_df, test_df = train_test_split(
    temp_df,
    test_size = SPLIT_RATIOS[2] / (SPLIT_RATIOS[1] + SPLIT_RATIOS[2]),
    stratify   = temp_df['label'],
    random_state = RANDOM_STATE
)

splits = {
    'train': train_df,
    'val':   val_df,
    'test':  test_df
}

# ─── STEP 3: process & save ────────────────────────────────────────────────────
for split_name, subset in splits.items():
    print(f"\nProcessing {split_name} ({len(subset)} images)…")
    for _, row in subset.iterrows():
        src_path = row['filepath']
        label    = row['label']

        # read, resize
        img = cv2.imread(src_path)
        if img is None:
            print(" ✗ failed to read:", src_path)
            continue
        img_resized = cv2.resize(img, TARGET_SIZE)

        # color–space conversions (in memory)
        img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)
        img_hsv = cv2.cvtColor(img_resized, cv2.COLOR_BGR2HSV)

        # save the BGR resized image (you can load RGB/HSV on‐the‐fly later)
        out_dir  = os.path.join(OUTPUT_DIR, split_name, label)
        makedirs(out_dir)
        fname    = os.path.basename(src_path)
        out_path = os.path.join(out_dir, fname)
        cv2.imwrite(out_path, img_resized)


print("\nDone resizing & splitting into train/val/test folders.")
# Out:
# Processing train (5025 images)…
#
# Processing val (1077 images)…
#
# Processing test (1077 images)…
#
# Done resizing & splitting into train/val/test folders.

# %% [markdown]
# # Step 04: Segmentation of Infected Regions
#
# 1. **Configure** input/output paths (`Leaf_Crops_original` → `Segmented`) and set `masks/`, `overlays/` subfolders plus a 5×5 elliptical kernel.
# 2. **Define** `segment_lesions(img_bgr)`:
#    - Apply CLAHE on the Lab L-channel
#    - Otsu threshold the a-channel to isolate brown/yellow lesions
#    - Morphologically open/close to clean up
#    - Blend a red overlay via `cv2.addWeighted()`
# 3. **Iterate** over each class folder in `INPUT_DIR`, creating matching `Segmented/masks/<class>` and `Segmented/overlays/<class>` directories.
# 4. **Process** each `*.png` leaf crop:
#    - Load as RGBA, split into BGR + alpha
#    - Call `segment_lesions()` on the BGR image
#    - Zero out mask & overlay pixels where `alpha == 0`
#    - Save `<base>_mask.png` and `<base>_overlay.png` to their respective folders

# %%
import os
import cv2
import numpy as np

# ─── CONFIGURATION ────────────────────────────────────────────────────────────
INPUT_DIR    = 'Leaf_Crops_original'              # top‐level with class subfolders
OUTPUT_ROOT  = 'Segmented'    # where masks/overlays will go
MASK_SUBDIR  = 'masks'
OVER_SUBDIR  = 'overlays'
KERNEL_SIZE  = (5, 5)

# Make sure output dirs exist
for sub in (MASK_SUBDIR, OVER_SUBDIR):
    os.makedirs(os.path.join(OUTPUT_ROOT, sub), exist_ok=True)

def segment_lesions(img_bgr):
    """CLAHE + Otsu on Lab ‘a’ to isolate brown/yellow lesions."""
    lab   = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2LAB)
    L, A, B = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    L_eq  = clahe.apply(L)
    lab_eq = cv2.merge([L_eq, A, B])

    # Otsu threshold on the a-channel
    _, mask = cv2.threshold(
        lab_eq[:, :, 1], 0, 255,
        cv2.THRESH_BINARY + cv2.THRESH_OTSU
    )

    # Morphological cleanup
    kernel     = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, KERNEL_SIZE)
    mask_open  = cv2.morphologyEx(mask,  cv2.MORPH_OPEN,  kernel, iterations=2)
    mask_clean = cv2.morphologyEx(mask_open, cv2.MORPH_CLOSE, kernel, iterations=2)

    # Build a red‐tinted overlay of lesions
    overlay = img_bgr.copy()
    overlay[mask_clean > 0] = (0, 0, 255)
    blended = cv2.addWeighted(img_bgr, 0.7, overlay, 0.3, 0)

    return mask_clean, blended

# ─── PROCESS ─────────────────────────────────────────────────────────────────
for class_name in os.listdir(INPUT_DIR):
    class_in_dir  = os.path.join(INPUT_DIR, class_name)
    if not os.path.isdir(class_in_dir):
        continue

    # prepare mirror subfolders
    mask_out_dir = os.path.join(OUTPUT_ROOT, MASK_SUBDIR, class_name)
    over_out_dir = os.path.join(OUTPUT_ROOT, OVER_SUBDIR, class_name)
    os.makedirs(mask_out_dir, exist_ok=True)
    os.makedirs(over_out_dir, exist_ok=True)

    for fname in os.listdir(class_in_dir):
        if not fname.lower().endswith('.png'):
            continue
        in_path = os.path.join(class_in_dir, fname)

        # load RGBA leaf crop
        rgba = cv2.imread(in_path, cv2.IMREAD_UNCHANGED)
        if rgba is None or rgba.shape[2] != 4:
            print(f"Skipping {fname}: not a valid RGBA PNG")
            continue
        b, g, r, alpha = cv2.split(rgba)
        img_bgr        = cv2.merge([b, g, r])

        # segment lesions
        mask, overlay = segment_lesions(img_bgr)

        # zero out anything outside the leaf
        mask[alpha == 0]    = 0
        overlay[alpha == 0] = img_bgr[alpha == 0]

        # save
        base = os.path.splitext(fname)[0]
        cv2.imwrite(os.path.join(mask_out_dir, base + '_mask.png'),    mask)
        cv2.imwrite(os.path.join(over_out_dir, base + '_overlay.png'), overlay)

        print(f"Processed {class_name}/{fname}")

print("Done! Check your infected masks & overlays under:", OUTPUT_ROOT)
# Out:
# Processed Pepper__bell___Bacterial_spot/0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Spot 8964_leaf.png
# Processed Pepper__bell___Bacterial_spot/006adb74-934f-448f-a14f-62181742127b___JR_B.Spot 3395_leaf.png
# Processed Pepper__bell___Bacterial_spot/00f2e69a-1e56-412d-8a79-fdce794a17e4___JR_B.Spot 3132_leaf.png
# Processed Pepper__bell___Bacterial_spot/01613cd0-d3cd-4e96-945c-a312002037bf___JR_B.Spot 3262_leaf.png
# Processed Pepper__bell___Bacterial_spot/0169b9ac-07b9-4be1-8b85-da94481f05a4___NREC_B.Spot 9169_leaf.png
# Processed Pepper__bell___Bacterial_spot/018e494e-d2eb-468b-9d02-40219d9f4921___JR_B.Spot 9045_leaf.png
# Processed Pepper__bell___Bacterial_spot/01940b6d-7dea-4889-a7b8-a35f4e9bba34___NREC_B.Spot 9120_leaf.png
# Processed Pepper__bell___Bacterial_spot/01dfb88b-cd5a-420c-b163-51f5fe07b74d___JR_B.Spot 9091_leaf.png
# Processed Pepper__bell___Bacterial_spot/01ebc916-4793-40a3-b5e4-a32687e4fa3d___NREC_B.Spot 9125_leaf.png
# Processed Pepper__bell___Bacterial_spot/024623ab-be81-4d99-a653-c3be1495ce8e___JR_B.Spot 8889_leaf.png
# Processed Pepper__bell___Bacterial_spot/02baf62e-11e2-4dde-97fb-e369b57d55d3___JR_B.Spot 8971_leaf.png
# Processed Pepper__bell___Bacterial_spot/032aa7c4-0a95-4f09-b0bb-1242f4f32d82___NREC_B.Spot 1889_leaf.png
# Processed Pepper__bell___Bacterial_spot/03bb7042-3fd5-42e1-aa2c-d51d6843704c___JR_B.Spot 8925_leaf.png
# Processed Pepper__bell___Bacterial_spot/0448a226-3d3a-494d-a026-a92b048689c7___JR_B.Spot 8897_leaf.png
# Processed Pepper__bell___Bacterial_spot/0495b4d4-66a4-438c-862d-c483f08e4a95___JR_B.Spot 3288_leaf.png
# Processed Pepper__bell___Bacterial_spot/04d46cfb-9cc8-4083-82af-ca2bb57c8182___NREC_B.Spot 1814_leaf.png
# Processed Pepper__bell___Bacterial_spot/05287bcb-610b-440f-9337-c4ce98bc3bbe___JR_B.Spot 3327_leaf.png
# Processed Pepper__bell___Bacterial_spot/0558ff5a-45c7-4ea0-9479-3f71f0048208___JR_B.Spot 3183_leaf.png
# Processed Pepper__bell___Bacterial_spot/055a84c4-8286-4b44-816a-66b82d3bd4bc___NREC_B.Spot 9105_leaf.png
# Processed Pepper__bell___Bacterial_spot/0576dd21-3958-46a5-ab99-f9865371bd1a___NREC_B.Spot 1957_leaf.png
# Processed Pepper__bell___Bacterial_spot/05af15b5-fbda-4dab-a4ba-c783d531d24d___JR_B.Spot 3150_leaf.png
# Processed Pepper__bell___Bacterial_spot/05c6ea65-cce4-43da-b57b-a45321b0e51b___NREC_B.Spot 9048_leaf.png
# Processed Pepper__bell___Bacterial_spot/0694ee73-2dbc-4583-9d2d-2b053ef0475b___NREC_B.Spot 1798_leaf.png
# Processed Pepper__bell___Bacterial_spot/06d752a4-d4a5-439e-b374-231a2cc64032___NREC_B.Spot 1868_leaf.png
# Processed Pepper__bell___Bacterial_spot/0705b53e-4c54-4fce-9bc0-833db0619f3d___JR_B.Spot 9068_leaf.png
# Processed Pepper__bell___Bacterial_spot/0719e8e8-c1ae-4d5a-b29c-dbadc36d13f3___NREC_B.Spot 1947_leaf.png
# Processed Pepper__bell___Bacterial_spot/0726c166-3471-41a8-8fe6-18600e89e802___NREC_B.Spot 1812_leaf.png
# Processed Pepper__bell___Bacterial_spot/080b107a-192f-40ce-8942-d8ccca8dfc52___NREC_B.Spot 1872_leaf.png
# Processed Pepper__bell___Bacterial_spot/08485974-1e38-4e34-b296-fadd9cc26942___NREC_B.Spot 9193_leaf.png
# Processed Pepper__bell___Bacterial_spot/09035eae-2a1c-4718-8877-5270a1fe8462___JR_B.Spot 3280_leaf.png
# Processed Pepper__bell___Bacterial_spot/0915c9a9-25b0-4728-be01-86e5cecb57df___NREC_B.Spot 1816_leaf.png
# Processed Pepper__bell___Bacterial_spot/17c4557b-7a8f-4ded-b11c-6c5ba3532f37___JR_B.Spot 8824_leaf.png
# Processed Pepper__bell___Bacterial_spot/184221a3-0f0e-4acc-b5be-7b853349cd0d___JR_B.Spot 3286_leaf.png
# Processed Pepper__bell___Bacterial_spot/186f840e-086b-49fa-97a7-18628c6293f0___JR_B.Spot 3136_leaf.png
# Processed Pepper__bell___Bacterial_spot/188f102a-6f64-4180-9d38-f98b61aaec60___JR_B.Spot 9014_leaf.png
# Processed Pepper__bell___Bacterial_spot/18df58d7-c6ac-48e5-8cb0-596b70252a8e___NREC_B.Spot 9153_leaf.png
# Processed Pepper__bell___Bacterial_spot/197e7e21-9ddb-4fbe-a87e-2885a14c29d5___JR_B.Spot 9035_leaf.png
# Processed Pepper__bell___Bacterial_spot/197fdd19-46d1-46f7-8e79-aa9545f76ff0___JR_B.Spot 9000_leaf.png
# Processed Pepper__bell___Bacterial_spot/19a868e4-5e24-43e8-b61b-a41022340f8e___NREC_B.Spot 1886_leaf.png
# Processed Pepper__bell___Bacterial_spot/1a1af0c4-9e4a-4158-b982-f81d487a3b68___NREC_B.Spot 9148_leaf.png
# Processed Pepper__bell___Bacterial_spot/1ade72cf-f7e0-4282-92d9-614bf05289a0___NREC_B.Spot 1975_leaf.png
# Processed Pepper__bell___Bacterial_spot/1aeb4d06-0069-4fea-be9f-3200ac2e9373___NREC_B.Spot 1909_leaf.png
# Processed Pepper__bell___Bacterial_spot/1b0cfb07-f452-49e0-85ad-45f3f519ca7a___JR_B.Spot 9094_leaf.png
# Processed Pepper__bell___Bacterial_spot/1b589f92-a658-4e58-96de-db41acc411ce___JR_B.Spot 3239_leaf.png
# Processed Pepper__bell___Bacterial_spot/1b73d0ec-bad1-4d2d-878e-6aa209aa39d2___JR_B.Spot 9086_leaf.png
# Processed Pepper__bell___Bacterial_spot/1b8d3e98-43d9-441d-93ef-a359e6e9ddc2___NREC_B.Spot 9052_leaf.png
# Processed Pepper__bell___Bacterial_spot/1c0c1501-f362-49d0-9e99-e72006441c8c___JR_B.Spot 8869_leaf.png
# Processed Pepper__bell___Bacterial_spot/1cb295da-e568-4168-a29c-48ab980f3772___NREC_B.Spot 9250_leaf.png
# Processed Pepper__bell___Bacterial_spot/1cce64aa-6f9f-4ce1-b319-dbc4a012b240___JR_B.Spot 8998_leaf.png
# Processed Pepper__bell___Bacterial_spot/1d0e1dec-de79-4e26-b592-b174d7c95739___NREC_B.Spot 9186_leaf.png
# Processed Pepper__bell___Bacterial_spot/1d26f9c5-2f4e-4b1e-a7d6-a4e9584a3ab7___JR_B.Spot 8918_leaf.png
# Processed Pepper__bell___Bacterial_spot/1d2949cc-b0fa-4a29-8540-2983230c34e9___JR_B.Spot 9017_leaf.png
# Processed Pepper__bell___Bacterial_spot/1d35e088-7147-4bac-9cce-9330a3f5906d___NREC_B.Spot 9096_leaf.png
# Processed Pepper__bell___Bacterial_spot/1d46d97c-17ae-41e2-9ac3-6a984804760e___JR_B.Spot 8825_leaf.png
# Processed Pepper__bell___Bacterial_spot/260e0075-466d-4aa2-8ad6-825cce898cdb___JR_B.Spot 9065_leaf.png
# Processed Pepper__bell___Bacterial_spot/261bcab9-0dc9-4146-bd6b-7305732922d0___JR_B.Spot 9055_leaf.png
# Processed Pepper__bell___Bacterial_spot/264753e7-97b9-4f1e-a1c2-a9239eb691b9___JR_B.Spot 8866_leaf.png
# Processed Pepper__bell___Bacterial_spot/2679d7e8-de91-4864-8123-d5652069232e___JR_B.Spot 3375_leaf.png
# Processed Pepper__bell___Bacterial_spot/26ca895f-8155-4d26-a0ac-7e04a7487832___NREC_B.Spot 9222_leaf.png
# Processed Pepper__bell___Bacterial_spot/26ff38eb-796d-48db-a28a-09bbee4fe3e0___NREC_B.Spot 9111_leaf.png
# Processed Pepper__bell___Bacterial_spot/2700e5b5-295c-4378-b829-0e5989864380___NREC_B.Spot 9091_leaf.png
# Processed Pepper__bell___Bacterial_spot/27388bbc-c768-427c-94d4-c195af364507___JR_B.Spot 8935_leaf.png
# Processed Pepper__bell___Bacterial_spot/276e68d4-8a80-4260-a47d-da9eb588bb7b___JR_B.Spot 3319_leaf.png
# Processed Pepper__bell___Bacterial_spot/28462e1b-741c-4949-884f-e5c35375dab4___JR_B.Spot 3111_leaf.png
# Processed Pepper__bell___Bacterial_spot/284b0fae-ce3c-43e7-acc6-e9a22bd6eb6f___JR_B.Spot 9074_leaf.png
# Processed Pepper__bell___Bacterial_spot/286c3d56-edde-4185-89f2-048ee0e7d6aa___JR_B.Spot 3287_leaf.png
# Processed Pepper__bell___Bacterial_spot/28b0cad6-b695-4e4b-9cd1-27f2e43647e7___JR_B.Spot 9071_leaf.png
# Processed Pepper__bell___Bacterial_spot/28c448aa-4d2c-4a96-baf0-e7ed99ae2495___JR_B.Spot 3385_leaf.png
# Processed Pepper__bell___Bacterial_spot/28cb6224-3cd7-4336-aeaa-a864141d0d98___JR_B.Spot 8910_leaf.png
# Processed Pepper__bell___Bacterial_spot/28f23e77-e556-40c8-8bc2-835227732de2___JR_B.Spot 8848_leaf.png
# Processed Pepper__bell___Bacterial_spot/292d6666-67ca-4c4f-91e9-b7313fdd523c___NREC_B.Spot 9130_leaf.png
# Processed Pepper__bell___Bacterial_spot/29896da5-a228-4e67-8d23-930c40ebb03b___JR_B.Spot 8920_leaf.png
# Processed Pepper__bell___Bacterial_spot/2a8a3b2f-d65a-416b-a251-63bb89f448c3___JR_B.Spot 3322_leaf.png
# Processed Pepper__bell___Bacterial_spot/2adcf097-e515-49f1-9716-c0d06d8b52b4___NREC_B.Spot 1933_leaf.png
# Processed Pepper__bell___Bacterial_spot/2b562d10-5ccf-4f20-aadc-2e1480bd303e___JR_B.Spot 3256_leaf.png
# Processed Pepper__bell___Bacterial_spot/2b710a19-f4cd-4bcf-afbf-e48face96045___NREC_B.Spot 1931_leaf.png
# Processed Pepper__bell___Bacterial_spot/2b8c82d0-2e5d-483a-93eb-53192fa486c9___NREC_B.Spot 1858_leaf.png
# Processed Pepper__bell___Bacterial_spot/2bb75692-d488-406d-bce0-c7eab42557c5___NREC_B.Spot 1922_leaf.png
# Processed Pepper__bell___Bacterial_spot/2becae93-578d-44c6-8e74-056e59d15c8e___JR_B.Spot 3396_leaf.png
# Processed Pepper__bell___Bacterial_spot/2c13c040-2ce6-47c5-899c-8146cd774f79___NREC_B.Spot 1976_leaf.png
# Processed Pepper__bell___Bacterial_spot/2c4a898a-9812-423b-bd8a-419a09699270___JR_B.Spot 8853_leaf.png
# Processed Pepper__bell___Bacterial_spot/2c8e565d-14be-4cbe-8873-2aa25a86b98c___JR_B.Spot 8903_leaf.png
# Processed Pepper__bell___Bacterial_spot/2ca511f9-951d-4f34-89af-25fd1a609584___NREC_B.Spot 9138_leaf.png
# Processed Pepper__bell___Bacterial_spot/2cdea224-6f10-4a3d-a3f1-1debd1a42640___JR_B.Spot 8926_leaf.png
# Processed Pepper__bell___Bacterial_spot/2d553272-2101-4d56-9819-9f08de938418___NREC_B.Spot 9087_leaf.png
# Processed Pepper__bell___Bacterial_spot/2d5def2a-c79d-444e-88be-a5961c9107d0___JR_B.Spot 3249_leaf.png
# Processed Pepper__bell___Bacterial_spot/2d7488fa-f033-4c1c-bc1f-b70f86406127___NREC_B.Spot 1800_leaf.png
# Processed Pepper__bell___Bacterial_spot/2d9f1bf4-6409-488c-8992-92b2909822bd___JR_B.Spot 3342_leaf.png
# Processed Pepper__bell___Bacterial_spot/2def1cb7-36cf-4aed-a8e5-ad7864721a44___JR_B.Spot 8915_leaf.png
# Processed Pepper__bell___Bacterial_spot/2e400707-ea59-4355-889a-32d5e56c1e1c___NREC_B.Spot 1936_leaf.png
# Processed Pepper__bell___Bacterial_spot/2edf5fe8-706b-4ce7-8b59-dc6bfa4b6b42___JR_B.Spot 8823_leaf.png
# Processed Pepper__bell___Bacterial_spot/2f26c2e1-a13d-41c9-9adf-51fb0ad99785___NREC_B.Spot 1849_leaf.png
# Processed Pepper__bell___Bacterial_spot/2f9b46c7-fa77-4196-9ed1-f3f316182340___JR_B.Spot 8943_leaf.png
# Processed Pepper__bell___Bacterial_spot/2fd2f664-70aa-40d6-b770-bb839944ce18___JR_B.Spot 3261_leaf.png
# Processed Pepper__bell___Bacterial_spot/301b41f3-647f-4bd2-9adb-ef98c8b8c238___JR_B.Spot 3399_leaf.png
# Processed Pepper__bell___Bacterial_spot/3042800d-559d-4250-bb62-23c346259685___NREC_B.Spot 1980_leaf.png
# Processed Pepper__bell___Bacterial_spot/30559581-e3ea-4ac4-8e8b-ff8bbc44b014___JR_B.Spot 8832_leaf.png
# Processed Pepper__bell___Bacterial_spot/307ade58-8297-4ca9-b412-7ab20f837dc3___NREC_B.Spot 1861_leaf.png
# Processed Pepper__bell___Bacterial_spot/30956fb2-aec3-4e1d-bc10-ead8d1bd9c03___NREC_B.Spot 1835_leaf.png
# Processed Pepper__bell___Bacterial_spot/311c06b4-36e7-4fc7-840d-2f3f86d28ea5___JR_B.Spot 3350_leaf.png
# Processed Pepper__bell___Bacterial_spot/313665a9-0f55-4f00-9373-74bf7349e6a6___NREC_B.Spot 1982_leaf.png
# Processed Pepper__bell___Bacterial_spot/313c8e04-9195-4b11-9f63-72ce704f78f3___NREC_B.Spot 9245_leaf.png
# Processed Pepper__bell___Bacterial_spot/315668fd-452d-43c1-8a63-e3b4d3d634a7___JR_B.Spot 3097_leaf.png
# Processed Pepper__bell___Bacterial_spot/31add1a3-eab6-4c9c-946f-d85d89297a0e___NREC_B.Spot 1842_leaf.png
# Processed Pepper__bell___Bacterial_spot/3233e1db-99e9-4107-8711-c8b28a8bfda1___JR_B.Spot 3165_leaf.png
# Processed Pepper__bell___Bacterial_spot/32927179-338a-4157-ab64-d5bea77834c1___JR_B.Spot 8933_leaf.png
# Processed Pepper__bell___Bacterial_spot/3294ec88-cc8d-4e3a-af08-f2f9d7f4a73b___JR_B.Spot 3196_leaf.png
# Processed Pepper__bell___Bacterial_spot/32bc632f-7dfc-4a3a-b25a-f71fba5b02b1___JR_B.Spot 8967_leaf.png
# Processed Pepper__bell___Bacterial_spot/32cb493a-bfd1-48bf-b8eb-852ccaf7695b___JR_B.Spot 8873_leaf.png
# Processed Pepper__bell___Bacterial_spot/32d3951c-8c10-4e8f-b35c-81f7de2513c7___JR_B.Spot 3112_leaf.png
# Processed Pepper__bell___Bacterial_spot/3342ddb9-c0b2-44c1-90eb-035e207a5c8a___JR_B.Spot 3372_leaf.png
# Processed Pepper__bell___Bacterial_spot/33763f26-1135-458f-8b2b-34897b8bb647___JR_B.Spot 3323_leaf.png
# Processed Pepper__bell___Bacterial_spot/33941a5f-32df-4c22-956f-e6db538dac8d___JR_B.Spot 3344_leaf.png
# Processed Pepper__bell___Bacterial_spot/33952a4a-ef41-4eff-9a2a-35bbea1b6686___JR_B.Spot 3200_leaf.png
# Processed Pepper__bell___Bacterial_spot/33af0ec5-80ce-4e3c-ba72-42959820f651___JR_B.Spot 8996_leaf.png
# Processed Pepper__bell___Bacterial_spot/33f79c51-bc4b-46dc-bb41-7f84070dde74___JR_B.Spot 3122_leaf.png
# Processed Pepper__bell___Bacterial_spot/34a38a87-b06b-4a69-b0d0-9dade7f3c2ea___NREC_B.Spot 1978_leaf.png
# Processed Pepper__bell___Bacterial_spot/34b6c910-b4aa-416b-a89d-98f63be5055c___NREC_B.Spot 9201_leaf.png
# Processed Pepper__bell___Bacterial_spot/356984ef-4342-4233-a2e6-3db044cbd4b2___JR_B.Spot 3147_leaf.png
# Processed Pepper__bell___Bacterial_spot/357afd4d-f9d0-433b-8082-d9318a7f674a___NREC_B.Spot 9134_leaf.png
# Processed Pepper__bell___Bacterial_spot/35833444-02ab-4d4a-a7b7-76757ef56e59___JR_B.Spot 8839_leaf.png
# Processed Pepper__bell___Bacterial_spot/35a552c8-feba-4b4a-9aee-3833e8b1daea___NREC_B.Spot 9200_leaf.png
# Processed Pepper__bell___Bacterial_spot/35b1d344-1bb9-4976-9ba2-de290dd167dd___NREC_B.Spot 9056_leaf.png
# Processed Pepper__bell___Bacterial_spot/35ef7246-60e5-4bcc-bc1f-020eac1eacc2___JR_B.Spot 3298_leaf.png
# Processed Pepper__bell___Bacterial_spot/3610f357-8b9f-4f98-8e7f-c4297daf3b20___NREC_B.Spot 1971_leaf.png
# Processed Pepper__bell___Bacterial_spot/36223df9-bc20-4672-8938-6f1f60fb4a0e___NREC_B.Spot 1873_leaf.png
# Processed Pepper__bell___Bacterial_spot/365ab78f-6a75-49ef-acb8-44b8b21fac2c___NREC_B.Spot 9159_leaf.png
# Processed Pepper__bell___Bacterial_spot/36aa1467-175d-42d0-8da3-99e8ffd06fbe___NREC_B.Spot 1905_leaf.png
# Processed Pepper__bell___Bacterial_spot/3700475e-b0b1-4b8b-90bd-374be22dbfd0___NREC_B.Spot 1860_leaf.png
# Processed Pepper__bell___Bacterial_spot/376e68b6-818c-4ed5-97d2-ec9b0ac55bff___NREC_B.Spot 9102_leaf.png
# Processed Pepper__bell___Bacterial_spot/377f30e6-bf06-41d6-885e-85bfe5146a9b___NREC_B.Spot 9072_leaf.png
# Processed Pepper__bell___Bacterial_spot/378ed86f-f435-44e8-93b3-3e05aa569492___JR_B.Spot 8864_leaf.png
# Processed Pepper__bell___Bacterial_spot/37e9bf3a-85da-4114-8e69-185498b9a9af___JR_B.Spot 3337_leaf.png
# Processed Pepper__bell___Bacterial_spot/37fbacb5-ed9d-48f2-bf19-37656ff7c317___JR_B.Spot 3307_leaf.png
# Processed Pepper__bell___Bacterial_spot/380d0458-2f1e-432c-8adf-614143cba968___JR_B.Spot 8980_leaf.png
# Processed Pepper__bell___Bacterial_spot/384a0470-30f4-4f8a-bbc2-f2e2102b82dc___JR_B.Spot 3388_leaf.png
# Processed Pepper__bell___Bacterial_spot/389480c3-0209-45e3-b3ee-2447b22de68f___JR_B.Spot 9016_leaf.png
# Processed Pepper__bell___Bacterial_spot/38caf650-d4c8-483d-a75d-b20f12629563___JR_B.Spot 3161_leaf.png
# Processed Pepper__bell___Bacterial_spot/39875cb8-3958-46b9-a9dc-f810f353af5a___JR_B.Spot 3321_leaf.png
# Processed Pepper__bell___Bacterial_spot/39a17538-d200-4dac-8dad-d76566b6b199___NREC_B.Spot 9173_leaf.png
# Processed Pepper__bell___Bacterial_spot/39d02156-2d42-4927-aab3-20dd59810f69___NREC_B.Spot 9075_leaf.png
# Processed Pepper__bell___Bacterial_spot/3a03526d-0bf4-4898-9f0f-8a9c31afd3eb___JR_B.Spot 3380_leaf.png
# Processed Pepper__bell___Bacterial_spot/3a041cb2-cd43-4fcf-8f84-f559d40f1bd8___JR_B.Spot 9101_leaf.png
# Processed Pepper__bell___Bacterial_spot/3a56f122-0d06-45c2-bc2b-0636d42a7545___JR_B.Spot 9088_leaf.png
# Processed Pepper__bell___Bacterial_spot/3af826c4-e8d8-472f-b4cf-d1a34bc2cd35___NREC_B.Spot 9051_leaf.png
# Processed Pepper__bell___Bacterial_spot/3b03d630-d2a3-4c76-9c95-0783b50895d8___NREC_B.Spot 9168_leaf.png
# Processed Pepper__bell___Bacterial_spot/3b3fcf17-b337-4548-b27f-f2b501c035c0___NREC_B.Spot 1942_leaf.png
# Processed Pepper__bell___Bacterial_spot/3b58322b-64c3-4354-8612-93a6f50a096e___JR_B.Spot 3291_leaf.png
# Processed Pepper__bell___Bacterial_spot/3b9a94fb-856a-4576-94e3-6c16bf01118f___JR_B.Spot 8956_leaf.png
# Processed Pepper__bell___Bacterial_spot/3bb93b52-4419-4882-9a35-0533f48757df___JR_B.Spot 3311_leaf.png
# Processed Pepper__bell___Bacterial_spot/3bf80a4f-7a2b-4cdf-a93f-dfa12ddb4128___NREC_B.Spot 9233_leaf.png
# Processed Pepper__bell___Bacterial_spot/3c237d3f-7242-4009-a08a-b4eb7cd662fc___NREC_B.Spot 1969_leaf.png
# Processed Pepper__bell___Bacterial_spot/3cc682be-f9eb-4464-a385-7265d8871b03___NREC_B.Spot 1865_leaf.png
# Processed Pepper__bell___Bacterial_spot/3d0ebe4c-591f-490f-b389-cd8f424acbba___JR_B.Spot 9041_leaf.png
# Processed Pepper__bell___Bacterial_spot/3d203d3a-3614-4ddf-9956-0c6a12208c7e___JR_B.Spot 3391_leaf.png
# Processed Pepper__bell___Bacterial_spot/3d5f977b-126e-4c4b-b6c2-5d81a69cf2d0___JR_B.Spot 3220_leaf.png
# Processed Pepper__bell___Bacterial_spot/3d6a3d51-8a9f-42ff-b4bf-299778c3e0a8___JR_B.Spot 3184_leaf.png
# Processed Pepper__bell___Bacterial_spot/3d87a319-d032-4bac-9b6c-0160a23531b9___NREC_B.Spot 1853_leaf.png
# Processed Pepper__bell___Bacterial_spot/3da16030-36bd-4866-826f-70945a9f8b60___JR_B.Spot 8934_leaf.png
# Processed Pepper__bell___Bacterial_spot/3dcf00d5-a9c0-4920-8767-2355f3f85bc4___NREC_B.Spot 9218_leaf.png
# Processed Pepper__bell___Bacterial_spot/3ddc56a6-7b13-43ae-841a-c6f6818d001b___JR_B.Spot 3190_leaf.png
# Processed Pepper__bell___Bacterial_spot/3df25df9-50f7-4430-8853-0ab2d3ca2579___JR_B.Spot 9083_leaf.png
# Processed Pepper__bell___Bacterial_spot/3e71a4e5-32e9-404e-815c-95208f7a79fd___JR_B.Spot 3258_leaf.png
# Processed Pepper__bell___Bacterial_spot/3ecf6ae1-56d9-47c0-bedb-af7954dbc3c6___JR_B.Spot 8953_leaf.png
# Processed Pepper__bell___Bacterial_spot/3f365db3-6af8-4113-97f1-1c8771cab676___NREC_B.Spot 1789_leaf.png
# Processed Pepper__bell___Bacterial_spot/3f436076-8f23-46e8-a730-08bffac34ea4___JR_B.Spot 3379_leaf.png
# Processed Pepper__bell___Bacterial_spot/3f4bec2b-fc05-4b3a-89aa-36960c25ecd1___JR_B.Spot 3207_leaf.png
# Processed Pepper__bell___Bacterial_spot/3fdbfdf3-ae31-49eb-8012-04cb4d3fc051___NREC_B.Spot 1973_leaf.png
# Processed Pepper__bell___Bacterial_spot/3ff12256-cb79-4a74-8c2f-2df51b31d646___NREC_B.Spot 9242_leaf.png
# Processed Pepper__bell___Bacterial_spot/4040f0a8-b1e5-47e9-b8ad-521818bf8c52___NREC_B.Spot 9202_leaf.png
# Processed Pepper__bell___Bacterial_spot/411c6355-117b-4762-80d9-d78556c4e9a1___NREC_B.Spot 1815_leaf.png
# Processed Pepper__bell___Bacterial_spot/41410a16-32af-4080-92a7-fd2869d5b48d___JR_B.Spot 9085_leaf.png
# Processed Pepper__bell___Bacterial_spot/418e8c33-046a-4056-99a6-83f20ba017fa___JR_B.Spot 3300_leaf.png
# Processed Pepper__bell___Bacterial_spot/41b580cc-85f0-42c5-aafc-d640ab727081___JR_B.Spot 8950_leaf.png
# Processed Pepper__bell___Bacterial_spot/41b84d9f-07b5-49a9-b928-b9be65ea5e3d___JR_B.Spot 3153_leaf.png
# Processed Pepper__bell___Bacterial_spot/41c041c0-d17a-4be1-b2b8-a46a816fbda5___NREC_B.Spot 9192_leaf.png
# Processed Pepper__bell___Bacterial_spot/41da62b7-c3af-4604-aaa5-c457356e04bd___JR_B.Spot 9034_leaf.png
# Processed Pepper__bell___Bacterial_spot/41f3e9be-44a8-42b1-9654-8e7127bfc57e___JR_B.Spot 9048_leaf.png
# Processed Pepper__bell___Bacterial_spot/41fed9b9-d409-4b56-a9d6-3e98f31a4e3a___JR_B.Spot 3275_leaf.png
# Processed Pepper__bell___Bacterial_spot/42268507-28e9-4fb2-bd74-a2afdb3eebfa___JR_B.Spot 3240_leaf.png
# Processed Pepper__bell___Bacterial_spot/423247c0-70c3-4d41-b22f-33071ee36a7a___JR_B.Spot 3246_leaf.png
# Processed Pepper__bell___Bacterial_spot/424602ec-36eb-425c-8bd9-73be3e544cf2___NREC_B.Spot 9251_leaf.png
# Processed Pepper__bell___Bacterial_spot/42b527a8-b3a7-47ae-981b-91727cd2f7e5___JR_B.Spot 3306_leaf.png
# Processed Pepper__bell___Bacterial_spot/42ec2c4f-8cb7-47b2-ba27-0950b0b18395___NREC_B.Spot 9143_leaf.png
# Processed Pepper__bell___Bacterial_spot/42ef264d-f255-4674-885a-0921a0e7f649___JR_B.Spot 9022_leaf.png
# Processed Pepper__bell___Bacterial_spot/4307f7a4-e666-40ee-a2b5-ff9c4e3e70e1___JR_B.Spot 3109_leaf.png
# Processed Pepper__bell___Bacterial_spot/435993b8-c7f7-47fd-85ad-bdb04ab3e8bb___JR_B.Spot 8976_leaf.png
# Processed Pepper__bell___Bacterial_spot/4396fc84-fea6-4cfd-a352-01241e44efda___NREC_B.Spot 1927_leaf.png
# Processed Pepper__bell___Bacterial_spot/43aa27d3-3a37-4245-8b20-984512abfc6c___JR_B.Spot 3386_leaf.png
# Processed Pepper__bell___Bacterial_spot/43fb5703-5a76-47cf-b027-42a9bd601401___JR_B.Spot 9033_leaf.png
# Processed Pepper__bell___Bacterial_spot/4420dd15-6c5f-4631-b21e-7db8fa5bd405___JR_B.Spot 3290_leaf.png
# Processed Pepper__bell___Bacterial_spot/442f9778-71fb-43c6-9b97-e11f6525a0f3___JR_B.Spot 3177_leaf.png
# Processed Pepper__bell___Bacterial_spot/4434e395-4f3d-435d-9101-ece6be005fd6___JR_B.Spot 8928_leaf.png
# Processed Pepper__bell___Bacterial_spot/447735c7-b650-4ef6-a53b-8fb661470de3___JR_B.Spot 3370_leaf.png
# Processed Pepper__bell___Bacterial_spot/4495c311-4a29-4d3b-9805-e63ec24e805f___JR_B.Spot 9082_leaf.png
# Processed Pepper__bell___Bacterial_spot/44dd61ff-4a53-4657-8340-4bd56d8d5dae___JR_B.Spot 8911_leaf.png
# Processed Pepper__bell___Bacterial_spot/45820fd3-e954-4baf-85cb-23175212dc0d___JR_B.Spot 8844_leaf.png
# Processed Pepper__bell___Bacterial_spot/4591498b-f2d2-4138-b603-8f734df28c1b___NREC_B.Spot 9063_leaf.png
# Processed Pepper__bell___Bacterial_spot/45c9c618-5b71-4d9d-a08a-4bd3ceaa0be4___NREC_B.Spot 9178_leaf.png
# Processed Pepper__bell___Bacterial_spot/45cfd1ee-052e-43ef-93ff-ae392eedd726___NREC_B.Spot 9084_leaf.png
# Processed Pepper__bell___Bacterial_spot/45de9eff-47b2-4e93-941a-11eeedbefc4f___NREC_B.Spot 1945_leaf.png
# Processed Pepper__bell___Bacterial_spot/4614ed01-e120-4ae9-8f13-028fa8297873___JR_B.Spot 8985_leaf.png
# Processed Pepper__bell___Bacterial_spot/4617631e-a75a-4cd0-a1f5-c06ed41a182a___JR_B.Spot 3281_leaf.png
# Processed Pepper__bell___Bacterial_spot/462d2266-b71d-4bd0-b1da-8bf71439f5cd___JR_B.Spot 3192_leaf.png
# Processed Pepper__bell___Bacterial_spot/46372226-cfbe-4206-951b-93b8b411d2e7___JR_B.Spot 8890_leaf.png
# Processed Pepper__bell___Bacterial_spot/46414704-3483-4a44-b786-6b8ee1814ed7___NREC_B.Spot 9133_leaf.png
# Processed Pepper__bell___Bacterial_spot/4683ce17-7653-4718-95a5-7158f3094640___NREC_B.Spot 9196_leaf.png
# Processed Pepper__bell___Bacterial_spot/4702d273-50d0-4b7c-b759-7ef62cdb441f___NREC_B.Spot 1828_leaf.png
# Processed Pepper__bell___Bacterial_spot/475f941c-242c-42e1-9149-ace60e32b931___NREC_B.Spot 9208_leaf.png
# Processed Pepper__bell___Bacterial_spot/4777008f-3144-44df-b230-e94725e711d2___NREC_B.Spot 1979_leaf.png
# Processed Pepper__bell___Bacterial_spot/47773ddb-e400-4a5d-87ec-ce711044c31e___NREC_B.Spot 9235_leaf.png
# Processed Pepper__bell___Bacterial_spot/47fbd17d-c078-4465-8816-c675abd9c850___JR_B.Spot 3185_leaf.png
# Processed Pepper__bell___Bacterial_spot/48a7cf31-19e0-45ba-89c1-7887afa0bdd4___JR_B.Spot 9095_leaf.png
# Processed Pepper__bell___Bacterial_spot/490afec2-acdf-4b61-b137-43d43285817c___JR_B.Spot 8949_leaf.png
# Processed Pepper__bell___Bacterial_spot/4911efb7-feaf-4602-a028-68b77294c06f___JR_B.Spot 3255_leaf.png
# Processed Pepper__bell___Bacterial_spot/4995d36f-321f-4f9e-82c8-9a0c78d1f266___NREC_B.Spot 9076_leaf.png
# Processed Pepper__bell___Bacterial_spot/49df8e8e-ecbb-4a62-b417-16f662d67b09___JR_B.Spot 9042_leaf.png
# Processed Pepper__bell___Bacterial_spot/4a18013a-dcd1-4974-b841-89c49b198a11___NREC_B.Spot 1984_leaf.png
# Processed Pepper__bell___Bacterial_spot/4a1ba341-501b-4f74-879b-61a9e29a8f9a___NREC_B.Spot 9211_leaf.png
# Processed Pepper__bell___Bacterial_spot/4aa16bda-c8f4-40b1-9f68-16bc936e6e9e___JR_B.Spot 3157_leaf.png
# Processed Pepper__bell___Bacterial_spot/4b5d5cc8-6df9-4963-8e68-1aaf3e8f2363___JR_B.Spot 3358_leaf.png
# Processed Pepper__bell___Bacterial_spot/4b70a1bf-7bee-41d1-b4ff-415307d6d1ca___NREC_B.Spot 1808_leaf.png
# Processed Pepper__bell___Bacterial_spot/4bad40b0-af40-4deb-820c-edbcbb9ea372___NREC_B.Spot 1843_leaf.png
# Processed Pepper__bell___Bacterial_spot/4bfd707f-94f4-442d-9dfc-8a96b51653d4___JR_B.Spot 3334_leaf.png
# Processed Pepper__bell___Bacterial_spot/4c1f3e8b-4c85-4554-b1d7-25feca1f58b3___JR_B.Spot 3250_leaf.png
# Processed Pepper__bell___Bacterial_spot/4c234632-b720-420d-934f-95b83f2dd59d___JR_B.Spot 3131_leaf.png
# Processed Pepper__bell___Bacterial_spot/4c2444b0-9bf1-4672-a118-dbde778fdab0___JR_B.Spot 8937_leaf.png
# Processed Pepper__bell___Bacterial_spot/4c34e3ed-523a-414d-b28d-52078277cb67___NREC_B.Spot 9174_leaf.png
# Processed Pepper__bell___Bacterial_spot/4c664b0a-9ee7-48c2-aaf4-d54e34f5edd3___JR_B.Spot 9060_leaf.png
# Processed Pepper__bell___Bacterial_spot/4c6a8199-896f-4cbf-8db4-3baa021a9e1c___NREC_B.Spot 9247_leaf.png
# Processed Pepper__bell___Bacterial_spot/4cda1135-6cad-421b-9648-d00f9f3cd16f___JR_B.Spot 3304_leaf.png
# Processed Pepper__bell___Bacterial_spot/4cf90b49-1b89-422e-84ae-2e2fcfc2fa02___JR_B.Spot 3362_leaf.png
# Processed Pepper__bell___Bacterial_spot/4d035250-f831-438b-a583-d192cbb26a55___JR_B.Spot 3163_leaf.png
# Processed Pepper__bell___Bacterial_spot/4d20e159-894a-4718-a9f8-e866e7c5a3d9___JR_B.Spot 9025_leaf.png
# Processed Pepper__bell___Bacterial_spot/4d42924a-13e0-4e26-b131-2125e154c542___NREC_B.Spot 9220_leaf.png
# Processed Pepper__bell___Bacterial_spot/4d9ffd2f-2740-42f0-9679-c00961ec8f71___NREC_B.Spot 9226_leaf.png
# Processed Pepper__bell___Bacterial_spot/4e380ba7-b5dc-46e3-850e-b52a775378d0___NREC_B.Spot 9107_leaf.png
# Processed Pepper__bell___Bacterial_spot/4eac0e27-27a7-49ad-80d7-6475aa904154___NREC_B.Spot 1896_leaf.png
# Processed Pepper__bell___Bacterial_spot/4ed61fe2-848f-40a3-ba6d-e81b0564bfec___JR_B.Spot 8865_leaf.png
# Processed Pepper__bell___Bacterial_spot/4f49f8c2-d091-40d0-b85c-db10099b3caa___NREC_B.Spot 9171_leaf.png
# Processed Pepper__bell___Bacterial_spot/4f539b76-13f8-43ab-a630-0cc6b1461bc9___JR_B.Spot 3381_leaf.png
# Processed Pepper__bell___Bacterial_spot/4fc91e77-fdbc-4041-a510-b267ebbc4bb9___NREC_B.Spot 9055_leaf.png
# Processed Pepper__bell___Bacterial_spot/505ac655-cca9-479c-8a2f-35a01b9030cf___JR_B.Spot 8836_leaf.png
# Processed Pepper__bell___Bacterial_spot/507d59c4-b6a3-4d94-bbfb-fd763b4033ad___JR_B.Spot 3223_leaf.png
# Processed Pepper__bell___Bacterial_spot/50d0c9c6-94ad-46aa-a94f-5a595eb65998___NREC_B.Spot 1946_leaf.png
# Processed Pepper__bell___Bacterial_spot/50e6a99b-97a6-4f91-bb0d-b82e11e3f482___NREC_B.Spot 9195_leaf.png
# Processed Pepper__bell___Bacterial_spot/51185964-48e2-493e-a052-42139dd0facd___JR_B.Spot 3331_leaf.png
# Processed Pepper__bell___Bacterial_spot/51227dc9-baed-4d63-92ec-70f3361b480b___NREC_B.Spot 9161_leaf.png
# Processed Pepper__bell___Bacterial_spot/514076ce-e366-4b68-a736-9346cd9a5f61___NREC_B.Spot 9190_leaf.png
# Processed Pepper__bell___Bacterial_spot/5149fd50-acad-4a4f-a098-a5378d31479e___NREC_B.Spot 9142_leaf.png
# Processed Pepper__bell___Bacterial_spot/517e3352-9e28-4b42-970b-2aa198203960___JR_B.Spot 8855_leaf.png
# Processed Pepper__bell___Bacterial_spot/51f564c9-28a3-4352-960c-9d88445d36d9___NREC_B.Spot 1794_leaf.png
# Processed Pepper__bell___Bacterial_spot/5220d08b-9ead-4c12-9a25-7044d1669d0d___JR_B.Spot 3208_leaf.png
# Processed Pepper__bell___Bacterial_spot/524b0b87-2adb-409c-acd6-02327fb7a064___NREC_B.Spot 9212_leaf.png
# Processed Pepper__bell___Bacterial_spot/525555a6-c09c-4551-8b9d-d2a8050f474d___JR_B.Spot 3355_leaf.png
# Processed Pepper__bell___Bacterial_spot/531eb612-a03c-45a5-95b4-d141d50dd0dc___JR_B.Spot 3203_leaf.png
# Processed Pepper__bell___Bacterial_spot/532c9cb3-3018-4217-b59c-c16b8473423d___JR_B.Spot 3339_leaf.png
# Processed Pepper__bell___Bacterial_spot/532fab13-878e-4fe9-af94-302ed3e0a906___NREC_B.Spot 1885_leaf.png
# Processed Pepper__bell___Bacterial_spot/536247a1-295f-455f-ab45-0798d5efa080___JR_B.Spot 8887_leaf.png
# Processed Pepper__bell___Bacterial_spot/5373b361-a0ee-477a-b8e9-f889d062ac1c___JR_B.Spot 3209_leaf.png
# Processed Pepper__bell___Bacterial_spot/538ad66b-39cb-4972-8ad7-8ebf1964f782___JR_B.Spot 9001_leaf.png
# Processed Pepper__bell___Bacterial_spot/5393f88f-ab0b-4b96-bc56-a76eeb106095___JR_B.Spot 8851_leaf.png
# Processed Pepper__bell___Bacterial_spot/539b8a7d-f257-49ff-81b8-76f39b5ac752___NREC_B.Spot 1805_leaf.png
# Processed Pepper__bell___Bacterial_spot/5528b2f7-3c8f-4c20-8fdc-5fa996e9a637___JR_B.Spot 3236_leaf.png
# Processed Pepper__bell___Bacterial_spot/55724053-6819-47ec-b9e1-84c5be15929e___JR_B.Spot 3205_leaf.png
# Processed Pepper__bell___Bacterial_spot/5577c999-dcb2-473a-8455-9972b4ff19ea___NREC_B.Spot 9205_leaf.png
# Processed Pepper__bell___Bacterial_spot/5579d5a5-ca6a-4a13-ae08-4f791fdc2e2a___NREC_B.Spot 1826_leaf.png
# Processed Pepper__bell___Bacterial_spot/557f35cb-b34b-4dc5-959b-efad147d5e88___JR_B.Spot 3382_leaf.png
# Processed Pepper__bell___Bacterial_spot/55d4d62f-ed27-4225-8245-c0e732a5a01b___JR_B.Spot 8959_leaf.png
# Processed Pepper__bell___Bacterial_spot/560d432a-7524-4482-8b49-1e64767da58b___JR_B.Spot 8831_leaf.png
# Processed Pepper__bell___Bacterial_spot/5640520e-087c-41ae-b462-c30d8aa51aab___JR_B.Spot 8914_leaf.png
# Processed Pepper__bell___Bacterial_spot/56a3748f-881d-4adb-ab0a-85b5cc6883a9___NREC_B.Spot 9180_leaf.png
# Processed Pepper__bell___Bacterial_spot/56c2ec78-14d2-4445-be5d-77a8db483e2a___NREC_B.Spot 1803_leaf.png
# Processed Pepper__bell___Bacterial_spot/56d81c17-6145-4887-af27-ea9c6dd64b33___NREC_B.Spot 9068_leaf.png
# Processed Pepper__bell___Bacterial_spot/5724817a-2d5d-4664-9388-d208c21bc09e___NREC_B.Spot 1953_leaf.png
# Processed Pepper__bell___Bacterial_spot/57337b7c-f7b3-4ed0-a249-921df1351cf1___JR_B.Spot 3243_leaf.png
# Processed Pepper__bell___Bacterial_spot/57d9d6f1-8f81-4b5b-8985-c82b136a6c4c___JR_B.Spot 8846_leaf.png
# Processed Pepper__bell___Bacterial_spot/57ff0455-861f-4f25-9598-c2954ca44027___JR_B.Spot 3115_leaf.png
# Processed Pepper__bell___Bacterial_spot/58797902-c466-4226-b913-dcd09c9e026f___NREC_B.Spot 1844_leaf.png
# Processed Pepper__bell___Bacterial_spot/58e3b37c-5192-4a03-9f8a-da00330c529a___NREC_B.Spot 9237_leaf.png
# Processed Pepper__bell___Bacterial_spot/58fe22f7-f357-448a-b0aa-ebad44a91f3d___JR_B.Spot 8895_leaf.png
# Processed Pepper__bell___Bacterial_spot/5979f1be-c7a6-47c5-b438-60c3eab4218e___JR_B.Spot 9093_leaf.png
# Processed Pepper__bell___Bacterial_spot/598fe617-af0b-49c0-ad10-f616bd4e0783___NREC_B.Spot 1847_leaf.png
# Processed Pepper__bell___Bacterial_spot/59b6bff9-4aca-4bf4-a129-21179e9cebae___JR_B.Spot 9069_leaf.png
# Processed Pepper__bell___Bacterial_spot/5a41f26f-19c9-43bc-8032-553300c7f7ff___JR_B.Spot 3125_leaf.png
# Processed Pepper__bell___Bacterial_spot/5b00e7ef-db0e-43d3-9d4c-db2d8ee2fac3___JR_B.Spot 3360_leaf.png
# Processed Pepper__bell___Bacterial_spot/63c47e0e-b12a-4e10-953a-0dfed899991e___NREC_B.Spot 1918_leaf.png
# Processed Pepper__bell___Bacterial_spot/642a8e92-aaea-4f20-8b59-29b541cb2611___NREC_B.Spot 9183_leaf.png
# Processed Pepper__bell___Bacterial_spot/64367d1d-8954-432d-94bf-9ee75a812a85___NREC_B.Spot 1890_leaf.png
# Processed Pepper__bell___Bacterial_spot/644b37d1-495a-40ef-9cff-163a97016d71___JR_B.Spot 3269_leaf.png
# Processed Pepper__bell___Bacterial_spot/648a0b23-8a55-4530-a0a0-b04882298d24___NREC_B.Spot 1839_leaf.png
# Processed Pepper__bell___Bacterial_spot/6499df20-fea2-4b02-bd62-a88c813dd3db___NREC_B.Spot 1841_leaf.png
# Processed Pepper__bell___Bacterial_spot/64c23fb9-51a0-4690-bed5-47ab3af8c294___JR_B.Spot 9072_leaf.png
# Processed Pepper__bell___Bacterial_spot/64ed4b17-84ad-4088-b079-c02eceef5e7e___NREC_B.Spot 1958_leaf.png
# Processed Pepper__bell___Bacterial_spot/64f4dcf0-30b4-41b2-b5e6-6e6798c3202d___JR_B.Spot 8834_leaf.png
# Processed Pepper__bell___Bacterial_spot/6565f5ba-8e68-4d1a-b267-b12bfd73f3ef___JR_B.Spot 3252_leaf.png
# Processed Pepper__bell___Bacterial_spot/656dbf3a-3aee-46a5-80b9-a86953fc82c5___JR_B.Spot 8879_leaf.png
# Processed Pepper__bell___Bacterial_spot/65a84ec0-79dc-4ae3-bfce-81c3f4b50a08___JR_B.Spot 8858_leaf.png
# Processed Pepper__bell___Bacterial_spot/65a94537-481e-44d0-a1e1-d8ba6551247d___JR_B.Spot 3202_leaf.png
# Processed Pepper__bell___Bacterial_spot/65c3a8f9-9631-4b86-9ae3-28116c869247___JR_B.Spot 9005_leaf.png
# Processed Pepper__bell___Bacterial_spot/65d4487f-5ee0-4925-8e7f-ba4a61c76750___NREC_B.Spot 9070_leaf.png
# Processed Pepper__bell___Bacterial_spot/65de6d37-4ea5-4ac7-af08-a974eb5b501a___NREC_B.Spot 9106_leaf.png
# Processed Pepper__bell___Bacterial_spot/65fc5138-b38a-42d6-a892-1441585ceebd___NREC_B.Spot 9057_leaf.png
# Processed Pepper__bell___Bacterial_spot/66078e98-f5db-446d-8d34-f6268d8703e0___JR_B.Spot 3285_leaf.png
# Processed Pepper__bell___Bacterial_spot/665fd560-82b6-4af9-8f0a-0dbace910cb2___JR_B.Spot 9062_leaf.png
# Processed Pepper__bell___Bacterial_spot/66d4cd59-bc59-49cc-9a94-dafa07318fb4___JR_B.Spot 8975_leaf.png
# Processed Pepper__bell___Bacterial_spot/66dc5b26-4643-4c8b-a95b-d273ead3672b___JR_B.Spot 3191_leaf.png
# Processed Pepper__bell___Bacterial_spot/67b4af5b-0ca1-4e11-a7c1-179b4defa8fc___JR_B.Spot 8965_leaf.png
# Processed Pepper__bell___Bacterial_spot/67e58468-8546-4324-8e1e-ae10abf2cb5b___JR_B.Spot 9099_leaf.png
# Processed Tomato_Early_blight/630ad26e-4c4e-4cfa-aa4c-75b54b5e6395___RS_Erly.B 7658_leaf.png
# Processed Tomato_Early_blight/6376d980-2b10-4990-a58d-ca0e7dfc6af3___RS_Erly.B 8215_leaf.png
# Processed Tomato_Early_blight/647ccba0-4f5e-4c64-a7ea-a34c8a39a439___RS_Erly.B 7355_leaf.png
# Processed Tomato_Early_blight/6485f47f-79cf-455f-9d6c-dbb04ddb580f___RS_Erly.B 7576_leaf.png
# Processed Tomato_Early_blight/64d0749a-a83f-41da-a321-b03d61167454___RS_Erly.B 7846_leaf.png
# Processed Tomato_Early_blight/64e682a8-ff23-4b50-a656-72b090f5b43a___RS_Erly.B 9478_leaf.png
# Processed Tomato_Early_blight/64ef53fa-26cc-4734-8a94-6f83a108817f___RS_Erly.B 6348_leaf.png
# Processed Tomato_Early_blight/64fade29-cabf-4ec2-a5cf-8c7aeca19eea___RS_Erly.B 6427_leaf.png
# Processed Tomato_Early_blight/64fd8cac-b985-45c1-9a5d-5f2f49381047___RS_Erly.B 9494_leaf.png
# Processed Tomato_Early_blight/654d7c11-664e-47c0-a6aa-c5c45a07e386___RS_Erly.B 7799_leaf.png
# Done! Check your infected masks & overlays under: Segmented

# %% [markdown]
# # Step 05: Feature Extraction
#
# 1. **Configure** input directories (`Processed/<split>/<class>`) and mask root (`Segmented/masks/<class>`), plus splits `["train","val","test"]`.
# 2. **Iterate** over each split and class folder, listing images and corresponding `_mask.png` files.
# 3. **Load** each image and mask, **resize** the mask (nearest‐neighbor) to match the image if needed.
# 4. **Threshold** the mask to a boolean `lesion` map; skip if no lesion pixels.
# 5. **Extract color features**: mean & standard deviation per BGR channel over the lesion region.
# 6. **Extract shape features**: contour area, perimeter, roundness, and bounding‐box aspect ratio.
# 7. **Append** all features plus `split`, `label`, `filename` into a records list, then **build** a DataFrame and **save** to `features_all_splits.csv`.

# %%
import os
import cv2
import numpy as np
import pandas as pd
from math import pi

# ─── CONFIGURATION ────────────────────────────────────────────────────────────
PROCESSED_DIR = "Processed"   # root of resized train/val/test subfolders
MASK_ROOT     = "Segmented"   # contains `masks/{class_name}/..._mask.png`
SPLITS        = ["train", "val", "test"]

records = []

for split in SPLITS:
    proc_split_dir = os.path.join(PROCESSED_DIR, split)
    if not os.path.isdir(proc_split_dir):
        print(f"Skipping missing split: {split}")
        continue

    for class_name in os.listdir(proc_split_dir):
        proc_class_dir = os.path.join(proc_split_dir, class_name)
        if not os.path.isdir(proc_class_dir):
            continue

        # masks are in Segmented/masks/<class_name>/
        seg_mask_dir = os.path.join(MASK_ROOT, "masks", class_name)
        if not os.path.isdir(seg_mask_dir):
            print(f"  No mask folder for class '{class_name}', skipping.")
            continue

        images = [f for f in os.listdir(proc_class_dir)
                  if f.lower().endswith(('.jpg','jpeg','png'))]
        masks  = [f for f in os.listdir(seg_mask_dir)
                  if f.lower().endswith('_mask.png')]
        print(f"{split}/{class_name}: {len(images)} images, {len(masks)} masks")

        for fname in images:
            base      = os.path.splitext(fname)[0]
            img_path  = os.path.join(proc_class_dir, fname)
            mask_path = os.path.join(seg_mask_dir, f"{base}_mask.png")

            if not os.path.exists(mask_path):
                print(f"    ✗ missing mask for {fname}")
                continue

            img  = cv2.imread(img_path)
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            if img is None or mask is None:
                print(f"    ✗ failed to load {fname}")
                continue

            # ─── ensure mask & image share the same dimensions ────────────────
            h, w = img.shape[:2]
            if mask.shape[:2] != (h, w):
                mask = cv2.resize(mask, (w, h), interpolation=cv2.INTER_NEAREST)

            lesion = mask > 0
            if not lesion.any():
                print(f"    ⚠ no lesion pixels in {fname}")
                continue

            # ─── COLOR FEATURES ────────────────────────────────────────────────
            means = [img[:, :, c][lesion].mean() for c in range(3)]
            stds  = [img[:, :, c][lesion].std()  for c in range(3)]

            # ─── SHAPE FEATURES ───────────────────────────────────────────────
            cnts, _    = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            total_area = sum(cv2.contourArea(c) for c in cnts)
            total_per  = sum(cv2.arcLength(c, True)  for c in cnts)
            roundness  = (4 * pi * total_area / (total_per**2)) if total_per > 0 else 0

            ratios = []
            for c in cnts:
                x, y, w_cnt, h_cnt = cv2.boundingRect(c)
                if h_cnt > 0:
                    ratios.append(w_cnt / float(h_cnt))
            bbox_aspect = float(np.mean(ratios)) if ratios else 0

            # ─── APPEND FEATURE ROW ─────────────────────────────────────────
            records.append({
                'split':       split,
                'label':       class_name,
                'filename':    fname,
                'mean_B':      means[0], 'mean_G':  means[1], 'mean_R':  means[2],
                'std_B':       stds[0],  'std_G':   stds[1],  'std_R':   stds[2],
                'area':        total_area,
                'perimeter':   total_per,
                'roundness':   roundness,
                'bbox_aspect': bbox_aspect
            })

# ─── BUILD DATAFRAME & SAVE ───────────────────────────────────────────────────
df = pd.DataFrame(records)
df.to_csv('features_all_splits.csv', index=False)
print(f"\nExtracted features for {len(df)} images across splits {SPLITS}")
print("Saved to features_all_splits.csv")
# Out:
# train/Pepper__bell___Bacterial_spot: 698 images, 997 masks
# train/Pepper__bell___healthy: 1035 images, 1478 masks
# train/Potato___Early_blight: 700 images, 1000 masks
# train/Potato___healthy: 106 images, 152 masks
# train/Potato___Late_blight: 700 images, 1000 masks
# train/Tomato_Bacterial_spot: 1489 images, 2127 masks
# train/Tomato_Early_blight: 297 images, 425 masks
# val/Pepper__bell___Bacterial_spot: 149 images, 997 masks
# val/Pepper__bell___healthy: 222 images, 1478 masks
# val/Potato___Early_blight: 150 images, 1000 masks
# val/Potato___healthy: 23 images, 152 masks
# val/Potato___Late_blight: 150 images, 1000 masks
# val/Tomato_Bacterial_spot: 319 images, 2127 masks
# val/Tomato_Early_blight: 64 images, 425 masks
# test/Pepper__bell___Bacterial_spot: 150 images, 997 masks
# test/Pepper__bell___healthy: 221 images, 1478 masks
# test/Potato___Early_blight: 150 images, 1000 masks
# test/Potato___healthy: 23 images, 152 masks
# test/Potato___Late_blight: 150 images, 1000 masks
# test/Tomato_Bacterial_spot: 319 images, 2127 masks
# test/Tomato_Early_blight: 64 images, 425 masks
#
# Extracted features for 7179 images across splits ['train', 'val', 'test']
# Saved to features_all_splits.csv

# %% [markdown]
# # Step 06: Disease Prediction Model
#
# 1. **Load** `features_train_test.csv` and split into `train_df` / `test_df` by the `split` column.
# 2. **Scale** features with `StandardScaler` fitted on train, applied to test.
# 3. **Train** an SVM via `GridSearchCV(cv=5)` on the scaled train set, selecting best hyperparameters.
# 4. **Evaluate** on test: print accuracy, per-class precision/recall/F1, and confusion matrix.
# 5. **Define** `percent_white_on_leaf(mask_path, img_path)` to
#    - resize mask to match image,
#    - threshold to isolate leaf area,
#    - compute `% white (lesion) pixels over leaf pixels`.
# 6. **Loop** over each test sample, call that function, collect percentages.
# 7. **Append** `infected_pct_leaf` to `test_df` and save to CSV.

# %%
import os
import cv2
import numpy as np
import pandas as pd
import joblib

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# ─── CONFIGURATION ────────────────────────────────────────────────────────────
FEATURES_CSV   = 'features_all_splits.csv'  # or your features_train_test.csv if it includes val
PROCESSED_DIR  = 'Processed'                # has train/, val/, test/ subfolders
MASK_ROOT      = os.path.join('Segmented', 'masks')  # masks/<class_name>/*.png

# ─── STEP 1: LOAD FEATURES & SPLIT ─────────────────────────────────────────────
df      = pd.read_csv(FEATURES_CSV)
train_df = df[df['split'] == 'train']
val_df   = df[df['split'] == 'val']
test_df  = df[df['split'] == 'test']

def prepare_xy(df_split):
    X = df_split.drop(columns=['split','label','filename'])
    y = df_split['label']
    return X, y

X_train, y_train = prepare_xy(train_df)
X_test,  y_test  = prepare_xy(test_df)

# ─── STEP 2: SCALE FEATURES ───────────────────────────────────────────────────
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# ─── STEP 3: TRAIN SVM ────────────────────────────────────────────────────────
svc = SVC(probability=True, random_state=42)
param_grid = {
    'C':      [0.1, 1, 10],
    'kernel': ['linear','rbf'],
    'gamma':  ['scale','auto']
}
grid = GridSearchCV(svc, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid.fit(X_train_scaled, y_train)
print("Best SVM parameters:", grid.best_params_)
model = grid.best_estimator_

# ─── STEP 4: EVALUATE ON TEST SET ─────────────────────────────────────────────
y_pred = model.predict(X_test_scaled)
print(f"\nTest Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# ─── STEP 5: PERCENT WHITE PIXELS OVER LEAF AREA ───────────────────────────────
def percent_white_on_leaf(mask_path, img_path, leaf_thr=10):
    mask     = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    img_gray = cv2.imread(img_path,  cv2.IMREAD_GRAYSCALE)
    if mask is None or img_gray is None:
        return np.nan
    # resize mask if needed
    h, w = img_gray.shape
    if mask.shape != (h, w):
        mask = cv2.resize(mask, (w, h), interpolation=cv2.INTER_NEAREST)
    # leaf area by gray threshold
    leaf_mask = img_gray > leaf_thr
    leaf_area = leaf_mask.sum()
    if leaf_area == 0:
        return 0.0
    # lesions are white (>0)
    lesion_on_leaf = np.logical_and(mask > 0, leaf_mask)
    return lesion_on_leaf.sum() / leaf_area * 100

# ─── STEP 6: COMPUTE FOR ALL SPLITS ────────────────────────────────────────────
all_splits = [('train', train_df), ('val', val_df), ('test', test_df)]
pct_list = []
rows = []
for split, subset in all_splits:
    for _, row in subset.iterrows():
        label = row['label']
        fname = row['filename']
        base, _ = os.path.splitext(fname)
        img_path  = os.path.join(PROCESSED_DIR, split, label, fname)
        mask_path = os.path.join(MASK_ROOT, label, f"{base}_mask.png")
        pct = percent_white_on_leaf(mask_path, img_path)
        pct_list.append(pct)
        rows.append({
            **row.to_dict(),
            'infected_pct_leaf': pct
        })
        print(f"{split}/{label}/{fname} → {pct:.2f}%")

# ─── STEP 7: SAVE COMPLETE RESULTS ────────────────────────────────────────────
out_df = pd.DataFrame(rows)
out_df.to_csv('results_with_infected_area_all_splits.csv', index=False)
print("\nSaved all-splits results to 'results_with_infected_area_all_splits.csv'")
# Out:
# Best SVM parameters: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Test Accuracy: 0.8449
#
# Classification Report:
#                                 precision    recall  f1-score   support
#
# Pepper__bell___Bacterial_spot       0.79      0.83      0.81       150
#        Pepper__bell___healthy       0.85      0.92      0.88       221
#         Potato___Early_blight       0.92      0.83      0.87       150
#          Potato___Late_blight       0.83      0.78      0.80       150
#              Potato___healthy       0.79      0.48      0.59        23
#         Tomato_Bacterial_spot       0.86      0.95      0.91       319
#           Tomato_Early_blight       0.70      0.41      0.51        64
#
#                      accuracy                           0.84      1077
#                     macro avg       0.82      0.74      0.77      1077
#                  weighted avg       0.84      0.84      0.84      1077
#
# Confusion Matrix:
#  [[125  15   3   4   1   1   1]
#  [  6 203   2   0   0   9   1]
#  [  8   4 124   5   1   7   1]
#  [  5   0   2 117   0  21   5]
#  [  1  10   0   1  11   0   0]
#  [  2   3   1   6   0 304   3]
#  [ 11   5   3   8   1  10  26]]
# train/Pepper__bell___Bacterial_spot/0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Spot 8964_leaf.png → 10.58%
# train/Pepper__bell___Bacterial_spot/00f2e69a-1e56-412d-8a79-fdce794a17e4___JR_B.Spot 3132_leaf.png → 4.28%
# train/Pepper__bell___Bacterial_spot/01613cd0-d3cd-4e96-945c-a312002037bf___JR_B.Spot 3262_leaf.png → 3.60%
# train/Pepper__bell___Bacterial_spot/018e494e-d2eb-468b-9d02-40219d9f4921___JR_B.Spot 9045_leaf.png → 7.26%
# train/Pepper__bell___Bacterial_spot/01940b6d-7dea-4889-a7b8-a35f4e9bba34___NREC_B.Spot 9120_leaf.png → 4.91%
# train/Pepper__bell___Bacterial_spot/01dfb88b-cd5a-420c-b163-51f5fe07b74d___JR_B.Spot 9091_leaf.png → 13.31%
# train/Pepper__bell___Bacterial_spot/01ebc916-4793-40a3-b5e4-a32687e4fa3d___NREC_B.Spot 9125_leaf.png → 8.15%
# train/Pepper__bell___Bacterial_spot/024623ab-be81-4d99-a653-c3be1495ce8e___JR_B.Spot 8889_leaf.png → 5.97%
# train/Pepper__bell___Bacterial_spot/02baf62e-11e2-4dde-97fb-e369b57d55d3___JR_B.Spot 8971_leaf.png → 4.22%
# train/Pepper__bell___Bacterial_spot/032aa7c4-0a95-4f09-b0bb-1242f4f32d82___NREC_B.Spot 1889_leaf.png → 2.15%
# train/Pepper__bell___Bacterial_spot/03bb7042-3fd5-42e1-aa2c-d51d6843704c___JR_B.Spot 8925_leaf.png → 9.10%
# train/Pepper__bell___Bacterial_spot/04d46cfb-9cc8-4083-82af-ca2bb57c8182___NREC_B.Spot 1814_leaf.png → 6.17%
# train/Pepper__bell___Bacterial_spot/05287bcb-610b-440f-9337-c4ce98bc3bbe___JR_B.Spot 3327_leaf.png → 5.18%
# train/Pepper__bell___Bacterial_spot/0558ff5a-45c7-4ea0-9479-3f71f0048208___JR_B.Spot 3183_leaf.png → 9.94%
# train/Pepper__bell___Bacterial_spot/055a84c4-8286-4b44-816a-66b82d3bd4bc___NREC_B.Spot 9105_leaf.png → 4.44%
# train/Pepper__bell___Bacterial_spot/0576dd21-3958-46a5-ab99-f9865371bd1a___NREC_B.Spot 1957_leaf.png → 18.47%
# train/Pepper__bell___Bacterial_spot/0694ee73-2dbc-4583-9d2d-2b053ef0475b___NREC_B.Spot 1798_leaf.png → 4.65%
# train/Pepper__bell___Bacterial_spot/06d752a4-d4a5-439e-b374-231a2cc64032___NREC_B.Spot 1868_leaf.png → 6.53%
# train/Pepper__bell___Bacterial_spot/0705b53e-4c54-4fce-9bc0-833db0619f3d___JR_B.Spot 9068_leaf.png → 7.21%
# train/Pepper__bell___Bacterial_spot/0719e8e8-c1ae-4d5a-b29c-dbadc36d13f3___NREC_B.Spot 1947_leaf.png → 5.69%
# train/Pepper__bell___Bacterial_spot/0726c166-3471-41a8-8fe6-18600e89e802___NREC_B.Spot 1812_leaf.png → 8.75%
# train/Pepper__bell___Bacterial_spot/08485974-1e38-4e34-b296-fadd9cc26942___NREC_B.Spot 9193_leaf.png → 3.45%
# train/Pepper__bell___Bacterial_spot/09035eae-2a1c-4718-8877-5270a1fe8462___JR_B.Spot 3280_leaf.png → 7.75%
# train/Pepper__bell___Bacterial_spot/0915c9a9-25b0-4728-be01-86e5cecb57df___NREC_B.Spot 1816_leaf.png → 11.86%
# train/Pepper__bell___Bacterial_spot/092b3e29-d29a-482f-9207-3cd5fbed6710___JR_B.Spot 3238_leaf.png → 9.06%
# train/Pepper__bell___Bacterial_spot/0a0dbf1f-1131-496f-b337-169ec6693e6f___NREC_B.Spot 9241_leaf.png → 5.06%
# train/Pepper__bell___Bacterial_spot/0abffc81-6be8-4b17-a83c-4d2830e30382___JR_B.Spot 9076_leaf.png → 6.63%
# train/Pepper__bell___Bacterial_spot/0b27c03f-b3bc-4d96-9b76-6fbd779404b9___NREC_B.Spot 1799_leaf.png → 5.16%
# train/Pepper__bell___Bacterial_spot/0b47ce18-7cfe-45e8-b21e-b83cb6282455___JR_B.Spot 3162_leaf.png → 11.38%
# train/Pepper__bell___Bacterial_spot/0bd0f439-013b-40ed-a6d1-4e67e971d437___JR_B.Spot 3272_leaf.png → 9.07%
# train/Pepper__bell___Bacterial_spot/0c2392f6-3e69-4baf-b9f3-197623f6631a___JR_B.Spot 3176_leaf.png → 7.74%
# train/Pepper__bell___Bacterial_spot/0c4e75b2-e4aa-437e-815c-636271d66bec___JR_B.Spot 3244_leaf.png → 8.09%
# train/Pepper__bell___Bacterial_spot/0c6f6805-490e-438c-b9cd-3fd7ee29f31b___NREC_B.Spot 9123_leaf.png → 2.67%
# train/Pepper__bell___Bacterial_spot/0c99cb45-b4e0-4ade-bba5-fab3b678f0bb___JR_B.Spot 8912_leaf.png → 8.18%
# train/Pepper__bell___Bacterial_spot/0ce74db6-be9b-4c43-a104-6a3f9bcd2de2___NREC_B.Spot 1827_leaf.png → 22.39%
# train/Pepper__bell___Bacterial_spot/0d2635e7-df23-4ceb-b3ba-3af50bb58357___NREC_B.Spot 1874_leaf.png → 6.47%
# train/Pepper__bell___Bacterial_spot/0d8421cd-eebc-4018-b591-12352dd970a7___JR_B.Spot 3234_leaf.png → 8.67%
# train/Pepper__bell___Bacterial_spot/0d8445ac-6333-42b0-bf32-950a2dd83908___NREC_B.Spot 1862_leaf.png → 7.90%
# train/Pepper__bell___Bacterial_spot/0d9b55df-a8c0-4784-b1e4-957c8d679513___NREC_B.Spot 1825_leaf.png → 16.43%
# train/Pepper__bell___Bacterial_spot/0e57b44f-bb06-43ec-8688-5a7985b461e7___JR_B.Spot 8970_leaf.png → 5.66%
# train/Pepper__bell___Bacterial_spot/0f2b941b-cce2-46e1-a6e3-6924604e9926___NREC_B.Spot 9073_leaf.png → 2.81%
# train/Pepper__bell___Bacterial_spot/0f72db9c-d635-4415-9781-68937328aed2___NREC_B.Spot 9188_leaf.png → 9.29%
# train/Pepper__bell___Bacterial_spot/0fcbdf76-fcc4-4271-986a-9466a784d404___JR_B.Spot 3374_leaf.png → 8.43%
# train/Pepper__bell___Bacterial_spot/0fdb66e8-b17d-42c2-bc6d-30dcfab8fcae___JR_B.Spot 9058_leaf.png → 6.59%
# train/Pepper__bell___Bacterial_spot/0fe8a42b-b943-43d6-88c4-78abdcbfe02d___NREC_B.Spot 9236_leaf.png → 8.54%
# train/Pepper__bell___Bacterial_spot/1044c742-39a0-4b1a-984f-3cb2bdeda94b___NREC_B.Spot 9219_leaf.png → 3.02%
# train/Pepper__bell___Bacterial_spot/1092e87d-5d66-43cd-8344-43b393d86065___NREC_B.Spot 9244_leaf.png → 2.77%
# train/Pepper__bell___Bacterial_spot/10af9ff3-16c3-4cb0-8af0-71d3b8442206___NREC_B.Spot 9090_leaf.png → 4.02%
# train/Pepper__bell___Bacterial_spot/113d374f-8b12-454c-84cc-ee91043bc988___NREC_B.Spot 9146_leaf.png → 5.67%
# train/Pepper__bell___Bacterial_spot/11a23270-53e7-41b6-8c79-91caeaf9cfa6___JR_B.Spot 9050_leaf.png → 9.26%
# train/Pepper__bell___Bacterial_spot/11b85334-0029-430e-873d-9402bd9e5e9f___JR_B.Spot 9031_leaf.png → 10.16%
# train/Pepper__bell___Bacterial_spot/11e6ce0a-8511-485a-b22c-21b978d28e5e___JR_B.Spot 3383_leaf.png → 18.01%
# train/Pepper__bell___Bacterial_spot/121268d0-b5e9-452b-aa45-df90ddcc5ee5___JR_B.Spot 8876_leaf.png → 5.66%
# train/Pepper__bell___Bacterial_spot/1219f26f-a23a-4c2a-99f0-407fc785c74a___JR_B.Spot 3332_leaf.png → 8.29%
# train/Pepper__bell___Bacterial_spot/12342367-f62b-40d0-897b-77bd1edbd3d1___JR_B.Spot 3199_leaf.png → 11.16%
# train/Pepper__bell___Bacterial_spot/12c9c98f-afc9-4c12-8a97-007e5a40712a___NREC_B.Spot 9053_leaf.png → 9.50%
# train/Pepper__bell___Bacterial_spot/12f47cff-1a75-47ec-99d2-01720786e478___NREC_B.Spot 1859_leaf.png → 4.83%
# train/Pepper__bell___Bacterial_spot/131dd897-98e3-45f0-9b4a-48471c4cbf4c___JR_B.Spot 8845_leaf.png → 5.69%
# train/Pepper__bell___Bacterial_spot/1360c0b1-4eb4-491b-8544-738d3c420828___NREC_B.Spot 1977_leaf.png → 9.30%
# train/Pepper__bell___Bacterial_spot/1385e1e7-c7a5-4edb-8273-2f6a54c583fa___NREC_B.Spot 9128_leaf.png → 5.01%
# train/Pepper__bell___Bacterial_spot/13955856-c347-4039-ba30-09ea39d66534___NREC_B.Spot 9114_leaf.png → 5.91%
# train/Pepper__bell___Bacterial_spot/139a5c07-332c-4a2d-8bf2-bf33ce9184c6___NREC_B.Spot 1892_leaf.png → 20.89%
# train/Pepper__bell___Bacterial_spot/141a46fa-9293-4810-9cf6-b329346f8fb2___JR_B.Spot 8995_leaf.png → 7.28%
# train/Pepper__bell___Bacterial_spot/146d24cd-0c7e-458b-9f82-7b27525b04e4___JR_B.Spot 3329_leaf.png → 4.77%
# train/Pepper__bell___Bacterial_spot/14a96020-2720-43c5-8638-e70b90ebd573___JR_B.Spot 9039_leaf.png → 6.04%
# train/Pepper__bell___Bacterial_spot/14c4fd88-6d2a-4701-94ce-ab9e4b277f57___JR_B.Spot 8875_leaf.png → 5.71%
# train/Pepper__bell___Bacterial_spot/14fa67ae-6059-40e9-9eca-2c5000c1d9cd___NREC_B.Spot 9225_leaf.png → 8.28%
# train/Pepper__bell___Bacterial_spot/15f3b9e4-9127-4404-904b-173dbe878fd6___JR_B.Spot 3226_leaf.png → 10.32%
# train/Pepper__bell___Bacterial_spot/162f0add-8d7d-477f-a724-cdfc2cc7de77___NREC_B.Spot 9154_leaf.png → 8.17%
# train/Pepper__bell___Bacterial_spot/168a11c9-159b-468c-a6d9-07d0b61c42c9___JR_B.Spot 3193_leaf.png → 11.30%
# train/Pepper__bell___Bacterial_spot/1694ae00-3c5f-488c-9402-e65c70c73cf2___JR_B.Spot 3179_leaf.png → 11.47%
# train/Pepper__bell___Bacterial_spot/17000d8e-8095-4f00-b704-b94b1c531d8d___JR_B.Spot 3384_leaf.png → 19.34%
# train/Pepper__bell___Bacterial_spot/1732db7e-9901-46df-b20e-3ca49ff1dbad___NREC_B.Spot 1791_leaf.png → 5.29%
# train/Pepper__bell___Bacterial_spot/17557939-f9e2-435a-a4e7-f4d3cff8aa8b___JR_B.Spot 3107_leaf.png → 13.09%
# train/Pepper__bell___Bacterial_spot/17737361-6967-452a-ac5d-efebaa1d8a35___NREC_B.Spot 9127_leaf.png → 7.06%
# train/Pepper__bell___Bacterial_spot/177e323a-7c1d-41f2-a6b3-8ea30795054f___JR_B.Spot 8941_leaf.png → 7.51%
# train/Pepper__bell___Bacterial_spot/17c4557b-7a8f-4ded-b11c-6c5ba3532f37___JR_B.Spot 8824_leaf.png → 7.41%
# train/Pepper__bell___Bacterial_spot/184221a3-0f0e-4acc-b5be-7b853349cd0d___JR_B.Spot 3286_leaf.png → 6.43%
# train/Pepper__bell___Bacterial_spot/186f840e-086b-49fa-97a7-18628c6293f0___JR_B.Spot 3136_leaf.png → 9.02%
# train/Pepper__bell___Bacterial_spot/188f102a-6f64-4180-9d38-f98b61aaec60___JR_B.Spot 9014_leaf.png → 10.25%
# train/Pepper__bell___Bacterial_spot/18df58d7-c6ac-48e5-8cb0-596b70252a8e___NREC_B.Spot 9153_leaf.png → 5.50%
# train/Pepper__bell___Bacterial_spot/19a868e4-5e24-43e8-b61b-a41022340f8e___NREC_B.Spot 1886_leaf.png → 2.57%
# train/Pepper__bell___Bacterial_spot/1a1af0c4-9e4a-4158-b982-f81d487a3b68___NREC_B.Spot 9148_leaf.png → 5.20%
# train/Pepper__bell___Bacterial_spot/1ade72cf-f7e0-4282-92d9-614bf05289a0___NREC_B.Spot 1975_leaf.png → 8.83%
# train/Pepper__bell___Bacterial_spot/1aeb4d06-0069-4fea-be9f-3200ac2e9373___NREC_B.Spot 1909_leaf.png → 5.89%
# train/Pepper__bell___Bacterial_spot/1b0cfb07-f452-49e0-85ad-45f3f519ca7a___JR_B.Spot 9094_leaf.png → 21.57%
# train/Pepper__bell___Bacterial_spot/1b73d0ec-bad1-4d2d-878e-6aa209aa39d2___JR_B.Spot 9086_leaf.png → 8.34%
# train/Pepper__bell___Bacterial_spot/1b8d3e98-43d9-441d-93ef-a359e6e9ddc2___NREC_B.Spot 9052_leaf.png → 11.70%
# train/Pepper__bell___Bacterial_spot/1c0c1501-f362-49d0-9e99-e72006441c8c___JR_B.Spot 8869_leaf.png → 8.08%
# train/Pepper__bell___Bacterial_spot/1cb295da-e568-4168-a29c-48ab980f3772___NREC_B.Spot 9250_leaf.png → 13.13%
# train/Pepper__bell___Bacterial_spot/1cce64aa-6f9f-4ce1-b319-dbc4a012b240___JR_B.Spot 8998_leaf.png → 6.99%
# train/Pepper__bell___Bacterial_spot/1d0e1dec-de79-4e26-b592-b174d7c95739___NREC_B.Spot 9186_leaf.png → 10.29%
# train/Pepper__bell___Bacterial_spot/1d26f9c5-2f4e-4b1e-a7d6-a4e9584a3ab7___JR_B.Spot 8918_leaf.png → 16.52%
# train/Pepper__bell___Bacterial_spot/1d2949cc-b0fa-4a29-8540-2983230c34e9___JR_B.Spot 9017_leaf.png → 14.35%
# train/Pepper__bell___Bacterial_spot/1e1ee82b-592b-4158-a48b-347084647492___NREC_B.Spot 9046_leaf.png → 10.13%
# train/Pepper__bell___Bacterial_spot/1e6d8dc0-a694-47e0-af80-81ccabdfd591___JR_B.Spot 3308_leaf.png → 3.96%
# train/Pepper__bell___Bacterial_spot/1f3b1b11-4934-4c0b-b054-8f8a977b488c___JR_B.Spot 3373_leaf.png → 7.55%
# train/Pepper__bell___Bacterial_spot/1f838b54-c372-4b51-b398-6988377b2218___JR_B.Spot 8977_leaf.png → 4.87%
# train/Pepper__bell___Bacterial_spot/20a9aed4-ba56-413d-b88d-f4491cf184b3___JR_B.Spot 3265_leaf.png → 2.93%
# train/Pepper__bell___Bacterial_spot/21556c18-1833-43a9-86b2-8e7130b4dbce___JR_B.Spot 3230_leaf.png → 3.30%
# train/Pepper__bell___Bacterial_spot/21f7119e-d926-4be3-9ace-d6b26b280e64___JR_B.Spot 8837_leaf.png → 10.65%
# train/Pepper__bell___Bacterial_spot/2254cc78-9169-4f14-9ab9-d9d3949a5f69___JR_B.Spot 3295_leaf.png → 10.34%
# train/Pepper__bell___Bacterial_spot/22a8af9b-34c3-447d-bd82-559f7d2206af___JR_B.Spot 3289_leaf.png → 6.08%
# train/Pepper__bell___Bacterial_spot/22d71c45-e246-4210-bf3a-a0ce5eeacfb5___JR_B.Spot 8888_leaf.png → 7.41%
# train/Pepper__bell___Bacterial_spot/234f12c4-f47d-4712-8780-3e1e99bf4c42___JR_B.Spot 3174_leaf.png → 10.78%
# train/Pepper__bell___Bacterial_spot/23e657c9-1f08-4714-817b-48fd2f3e2cf3___JR_B.Spot 8962_leaf.png → 8.98%
# train/Pepper__bell___Bacterial_spot/2414f9df-91fd-4aed-b772-bd6b5311eb0b___JR_B.Spot 3141_leaf.png → 18.34%
# train/Pepper__bell___Bacterial_spot/2433614e-78d3-45ae-b719-59efb0397572___JR_B.Spot 8966_leaf.png → 9.94%
# train/Pepper__bell___Bacterial_spot/24783ea0-432e-4e74-b561-58b9d7fe88dc___NREC_B.Spot 9166_leaf.png → 9.57%
# train/Pepper__bell___Bacterial_spot/25d9d63d-08f1-45de-be1a-83ec25160b75___NREC_B.Spot 1919_leaf.png → 3.28%
# train/Pepper__bell___Bacterial_spot/264753e7-97b9-4f1e-a1c2-a9239eb691b9___JR_B.Spot 8866_leaf.png → 5.33%
# train/Pepper__bell___Bacterial_spot/2679d7e8-de91-4864-8123-d5652069232e___JR_B.Spot 3375_leaf.png → 6.27%
# train/Pepper__bell___Bacterial_spot/26ca895f-8155-4d26-a0ac-7e04a7487832___NREC_B.Spot 9222_leaf.png → 8.14%
# train/Pepper__bell___Bacterial_spot/26ff38eb-796d-48db-a28a-09bbee4fe3e0___NREC_B.Spot 9111_leaf.png → 8.91%
# train/Pepper__bell___Bacterial_spot/2700e5b5-295c-4378-b829-0e5989864380___NREC_B.Spot 9091_leaf.png → 6.28%
# train/Pepper__bell___Bacterial_spot/27388bbc-c768-427c-94d4-c195af364507___JR_B.Spot 8935_leaf.png → 5.44%
# train/Pepper__bell___Bacterial_spot/276e68d4-8a80-4260-a47d-da9eb588bb7b___JR_B.Spot 3319_leaf.png → 3.85%
# train/Pepper__bell___Bacterial_spot/28462e1b-741c-4949-884f-e5c35375dab4___JR_B.Spot 3111_leaf.png → 2.70%
# train/Pepper__bell___Bacterial_spot/286c3d56-edde-4185-89f2-048ee0e7d6aa___JR_B.Spot 3287_leaf.png → 5.30%
# train/Pepper__bell___Bacterial_spot/28b0cad6-b695-4e4b-9cd1-27f2e43647e7___JR_B.Spot 9071_leaf.png → 7.56%
# train/Pepper__bell___Bacterial_spot/292d6666-67ca-4c4f-91e9-b7313fdd523c___NREC_B.Spot 9130_leaf.png → 5.57%
# train/Pepper__bell___Bacterial_spot/29896da5-a228-4e67-8d23-930c40ebb03b___JR_B.Spot 8920_leaf.png → 13.91%
# train/Pepper__bell___Bacterial_spot/2a8a3b2f-d65a-416b-a251-63bb89f448c3___JR_B.Spot 3322_leaf.png → 4.30%
# train/Pepper__bell___Bacterial_spot/2adcf097-e515-49f1-9716-c0d06d8b52b4___NREC_B.Spot 1933_leaf.png → 5.70%
# train/Pepper__bell___Bacterial_spot/2b710a19-f4cd-4bcf-afbf-e48face96045___NREC_B.Spot 1931_leaf.png → 12.42%
# train/Pepper__bell___Bacterial_spot/2b8c82d0-2e5d-483a-93eb-53192fa486c9___NREC_B.Spot 1858_leaf.png → 5.43%
# train/Pepper__bell___Bacterial_spot/2bb75692-d488-406d-bce0-c7eab42557c5___NREC_B.Spot 1922_leaf.png → 4.54%
# train/Pepper__bell___Bacterial_spot/2c13c040-2ce6-47c5-899c-8146cd774f79___NREC_B.Spot 1976_leaf.png → 9.86%
# train/Pepper__bell___Bacterial_spot/2c4a898a-9812-423b-bd8a-419a09699270___JR_B.Spot 8853_leaf.png → 7.36%
# train/Pepper__bell___Bacterial_spot/2c8e565d-14be-4cbe-8873-2aa25a86b98c___JR_B.Spot 8903_leaf.png → 13.85%
# train/Pepper__bell___Bacterial_spot/2ca511f9-951d-4f34-89af-25fd1a609584___NREC_B.Spot 9138_leaf.png → 11.56%
# train/Pepper__bell___Bacterial_spot/2cdea224-6f10-4a3d-a3f1-1debd1a42640___JR_B.Spot 8926_leaf.png → 7.14%
# train/Pepper__bell___Bacterial_spot/2d553272-2101-4d56-9819-9f08de938418___NREC_B.Spot 9087_leaf.png → 7.68%
# train/Pepper__bell___Bacterial_spot/2d5def2a-c79d-444e-88be-a5961c9107d0___JR_B.Spot 3249_leaf.png → 4.84%
# train/Pepper__bell___Bacterial_spot/2d7488fa-f033-4c1c-bc1f-b70f86406127___NREC_B.Spot 1800_leaf.png → 4.84%
# train/Pepper__bell___Bacterial_spot/2d9f1bf4-6409-488c-8992-92b2909822bd___JR_B.Spot 3342_leaf.png → 5.10%
# train/Pepper__bell___Bacterial_spot/2def1cb7-36cf-4aed-a8e5-ad7864721a44___JR_B.Spot 8915_leaf.png → 6.11%
# train/Pepper__bell___Bacterial_spot/2e400707-ea59-4355-889a-32d5e56c1e1c___NREC_B.Spot 1936_leaf.png → 10.00%
# train/Pepper__bell___Bacterial_spot/2edf5fe8-706b-4ce7-8b59-dc6bfa4b6b42___JR_B.Spot 8823_leaf.png → 9.73%
# train/Pepper__bell___Bacterial_spot/2f9b46c7-fa77-4196-9ed1-f3f316182340___JR_B.Spot 8943_leaf.png → 8.33%
# train/Pepper__bell___Bacterial_spot/2fd2f664-70aa-40d6-b770-bb839944ce18___JR_B.Spot 3261_leaf.png → 2.39%
# train/Pepper__bell___Bacterial_spot/30559581-e3ea-4ac4-8e8b-ff8bbc44b014___JR_B.Spot 8832_leaf.png → 11.50%
# train/Pepper__bell___Bacterial_spot/30956fb2-aec3-4e1d-bc10-ead8d1bd9c03___NREC_B.Spot 1835_leaf.png → 10.37%
# train/Pepper__bell___Bacterial_spot/313665a9-0f55-4f00-9373-74bf7349e6a6___NREC_B.Spot 1982_leaf.png → 8.59%
# train/Pepper__bell___Bacterial_spot/313c8e04-9195-4b11-9f63-72ce704f78f3___NREC_B.Spot 9245_leaf.png → 6.03%
# train/Pepper__bell___Bacterial_spot/315668fd-452d-43c1-8a63-e3b4d3d634a7___JR_B.Spot 3097_leaf.png → 7.57%
# train/Pepper__bell___Bacterial_spot/31add1a3-eab6-4c9c-946f-d85d89297a0e___NREC_B.Spot 1842_leaf.png → 3.65%
# train/Pepper__bell___Bacterial_spot/3233e1db-99e9-4107-8711-c8b28a8bfda1___JR_B.Spot 3165_leaf.png → 12.86%
# train/Pepper__bell___Bacterial_spot/3294ec88-cc8d-4e3a-af08-f2f9d7f4a73b___JR_B.Spot 3196_leaf.png → 13.41%
# train/Pepper__bell___Bacterial_spot/32bc632f-7dfc-4a3a-b25a-f71fba5b02b1___JR_B.Spot 8967_leaf.png → 10.48%
# train/Pepper__bell___Bacterial_spot/33763f26-1135-458f-8b2b-34897b8bb647___JR_B.Spot 3323_leaf.png → 4.29%
# train/Pepper__bell___Bacterial_spot/33941a5f-32df-4c22-956f-e6db538dac8d___JR_B.Spot 3344_leaf.png → 4.82%
# train/Pepper__bell___Bacterial_spot/33f79c51-bc4b-46dc-bb41-7f84070dde74___JR_B.Spot 3122_leaf.png → 7.98%
# train/Pepper__bell___Bacterial_spot/34a38a87-b06b-4a69-b0d0-9dade7f3c2ea___NREC_B.Spot 1978_leaf.png → 9.50%
# train/Pepper__bell___Bacterial_spot/34b6c910-b4aa-416b-a89d-98f63be5055c___NREC_B.Spot 9201_leaf.png → 1.31%
# train/Pepper__bell___Bacterial_spot/356984ef-4342-4233-a2e6-3db044cbd4b2___JR_B.Spot 3147_leaf.png → 15.55%
# train/Pepper__bell___Bacterial_spot/357afd4d-f9d0-433b-8082-d9318a7f674a___NREC_B.Spot 9134_leaf.png → 6.13%
# train/Pepper__bell___Bacterial_spot/35833444-02ab-4d4a-a7b7-76757ef56e59___JR_B.Spot 8839_leaf.png → 10.14%
# train/Pepper__bell___Bacterial_spot/35a552c8-feba-4b4a-9aee-3833e8b1daea___NREC_B.Spot 9200_leaf.png → 7.67%
# train/Pepper__bell___Bacterial_spot/35ef7246-60e5-4bcc-bc1f-020eac1eacc2___JR_B.Spot 3298_leaf.png → 7.86%
# train/Pepper__bell___Bacterial_spot/365ab78f-6a75-49ef-acb8-44b8b21fac2c___NREC_B.Spot 9159_leaf.png → 6.88%
# train/Pepper__bell___Bacterial_spot/3700475e-b0b1-4b8b-90bd-374be22dbfd0___NREC_B.Spot 1860_leaf.png → 5.17%
# train/Pepper__bell___Bacterial_spot/376e68b6-818c-4ed5-97d2-ec9b0ac55bff___NREC_B.Spot 9102_leaf.png → 9.51%
# train/Pepper__bell___Bacterial_spot/377f30e6-bf06-41d6-885e-85bfe5146a9b___NREC_B.Spot 9072_leaf.png → 8.35%
# train/Pepper__bell___Bacterial_spot/378ed86f-f435-44e8-93b3-3e05aa569492___JR_B.Spot 8864_leaf.png → 5.03%
# train/Pepper__bell___Bacterial_spot/37fbacb5-ed9d-48f2-bf19-37656ff7c317___JR_B.Spot 3307_leaf.png → 3.76%
# train/Pepper__bell___Bacterial_spot/380d0458-2f1e-432c-8adf-614143cba968___JR_B.Spot 8980_leaf.png → 8.63%
# train/Pepper__bell___Bacterial_spot/384a0470-30f4-4f8a-bbc2-f2e2102b82dc___JR_B.Spot 3388_leaf.png → 20.26%
# train/Pepper__bell___Bacterial_spot/389480c3-0209-45e3-b3ee-2447b22de68f___JR_B.Spot 9016_leaf.png → 17.18%
# train/Pepper__bell___Bacterial_spot/38caf650-d4c8-483d-a75d-b20f12629563___JR_B.Spot 3161_leaf.png → 9.23%
# train/Pepper__bell___Bacterial_spot/39a17538-d200-4dac-8dad-d76566b6b199___NREC_B.Spot 9173_leaf.png → 2.76%
# train/Pepper__bell___Bacterial_spot/3a041cb2-cd43-4fcf-8f84-f559d40f1bd8___JR_B.Spot 9101_leaf.png → 16.16%
# train/Pepper__bell___Bacterial_spot/3a56f122-0d06-45c2-bc2b-0636d42a7545___JR_B.Spot 9088_leaf.png → 8.83%
# train/Pepper__bell___Bacterial_spot/3af826c4-e8d8-472f-b4cf-d1a34bc2cd35___NREC_B.Spot 9051_leaf.png → 11.54%
# train/Pepper__bell___Bacterial_spot/3b03d630-d2a3-4c76-9c95-0783b50895d8___NREC_B.Spot 9168_leaf.png → 8.00%
# train/Pepper__bell___Bacterial_spot/3b3fcf17-b337-4548-b27f-f2b501c035c0___NREC_B.Spot 1942_leaf.png → 12.33%
# train/Pepper__bell___Bacterial_spot/3b58322b-64c3-4354-8612-93a6f50a096e___JR_B.Spot 3291_leaf.png → 6.88%
# train/Pepper__bell___Bacterial_spot/3cc682be-f9eb-4464-a385-7265d8871b03___NREC_B.Spot 1865_leaf.png → 13.03%
# train/Pepper__bell___Bacterial_spot/3d0ebe4c-591f-490f-b389-cd8f424acbba___JR_B.Spot 9041_leaf.png → 5.62%
# train/Pepper__bell___Bacterial_spot/3d5f977b-126e-4c4b-b6c2-5d81a69cf2d0___JR_B.Spot 3220_leaf.png → 14.04%
# train/Pepper__bell___Bacterial_spot/3d6a3d51-8a9f-42ff-b4bf-299778c3e0a8___JR_B.Spot 3184_leaf.png → 8.68%
# train/Pepper__bell___Bacterial_spot/3d87a319-d032-4bac-9b6c-0160a23531b9___NREC_B.Spot 1853_leaf.png → 4.83%
# train/Pepper__bell___Bacterial_spot/3da16030-36bd-4866-826f-70945a9f8b60___JR_B.Spot 8934_leaf.png → 7.44%
# train/Pepper__bell___Bacterial_spot/3df25df9-50f7-4430-8853-0ab2d3ca2579___JR_B.Spot 9083_leaf.png → 8.19%
# train/Pepper__bell___Bacterial_spot/3e71a4e5-32e9-404e-815c-95208f7a79fd___JR_B.Spot 3258_leaf.png → 2.54%
# train/Pepper__bell___Bacterial_spot/3ecf6ae1-56d9-47c0-bedb-af7954dbc3c6___JR_B.Spot 8953_leaf.png → 6.45%
# train/Pepper__bell___Bacterial_spot/3f365db3-6af8-4113-97f1-1c8771cab676___NREC_B.Spot 1789_leaf.png → 6.78%
# train/Pepper__bell___Bacterial_spot/3f436076-8f23-46e8-a730-08bffac34ea4___JR_B.Spot 3379_leaf.png → 7.73%
# train/Pepper__bell___Bacterial_spot/3fdbfdf3-ae31-49eb-8012-04cb4d3fc051___NREC_B.Spot 1973_leaf.png → 10.77%
# train/Pepper__bell___Bacterial_spot/3ff12256-cb79-4a74-8c2f-2df51b31d646___NREC_B.Spot 9242_leaf.png → 5.08%
# train/Pepper__bell___Bacterial_spot/4040f0a8-b1e5-47e9-b8ad-521818bf8c52___NREC_B.Spot 9202_leaf.png → 1.42%
# train/Pepper__bell___Bacterial_spot/411c6355-117b-4762-80d9-d78556c4e9a1___NREC_B.Spot 1815_leaf.png → 8.75%
# train/Pepper__bell___Bacterial_spot/41410a16-32af-4080-92a7-fd2869d5b48d___JR_B.Spot 9085_leaf.png → 10.41%
# train/Pepper__bell___Bacterial_spot/418e8c33-046a-4056-99a6-83f20ba017fa___JR_B.Spot 3300_leaf.png → 4.37%
# train/Pepper__bell___Bacterial_spot/41b580cc-85f0-42c5-aafc-d640ab727081___JR_B.Spot 8950_leaf.png → 9.86%
# train/Pepper__bell___Bacterial_spot/41b84d9f-07b5-49a9-b928-b9be65ea5e3d___JR_B.Spot 3153_leaf.png → 11.44%
# train/Pepper__bell___Bacterial_spot/41da62b7-c3af-4604-aaa5-c457356e04bd___JR_B.Spot 9034_leaf.png → 6.49%
# train/Pepper__bell___Bacterial_spot/42268507-28e9-4fb2-bd74-a2afdb3eebfa___JR_B.Spot 3240_leaf.png → 7.30%
# train/Pepper__bell___Bacterial_spot/423247c0-70c3-4d41-b22f-33071ee36a7a___JR_B.Spot 3246_leaf.png → 8.21%
# train/Pepper__bell___Bacterial_spot/42b527a8-b3a7-47ae-981b-91727cd2f7e5___JR_B.Spot 3306_leaf.png → 5.69%
# train/Pepper__bell___Bacterial_spot/42ec2c4f-8cb7-47b2-ba27-0950b0b18395___NREC_B.Spot 9143_leaf.png → 5.40%
# train/Pepper__bell___Bacterial_spot/4307f7a4-e666-40ee-a2b5-ff9c4e3e70e1___JR_B.Spot 3109_leaf.png → 14.48%
# train/Pepper__bell___Bacterial_spot/435993b8-c7f7-47fd-85ad-bdb04ab3e8bb___JR_B.Spot 8976_leaf.png → 5.01%
# train/Pepper__bell___Bacterial_spot/43aa27d3-3a37-4245-8b20-984512abfc6c___JR_B.Spot 3386_leaf.png → 16.54%
# train/Pepper__bell___Bacterial_spot/43fb5703-5a76-47cf-b027-42a9bd601401___JR_B.Spot 9033_leaf.png → 8.82%
# train/Pepper__bell___Bacterial_spot/442f9778-71fb-43c6-9b97-e11f6525a0f3___JR_B.Spot 3177_leaf.png → 7.97%
# train/Pepper__bell___Bacterial_spot/4434e395-4f3d-435d-9101-ece6be005fd6___JR_B.Spot 8928_leaf.png → 5.78%
# train/Pepper__bell___Bacterial_spot/447735c7-b650-4ef6-a53b-8fb661470de3___JR_B.Spot 3370_leaf.png → 6.96%
# train/Pepper__bell___Bacterial_spot/4495c311-4a29-4d3b-9805-e63ec24e805f___JR_B.Spot 9082_leaf.png → 17.63%
# train/Pepper__bell___Bacterial_spot/44dd61ff-4a53-4657-8340-4bd56d8d5dae___JR_B.Spot 8911_leaf.png → 7.75%
# train/Pepper__bell___Bacterial_spot/4591498b-f2d2-4138-b603-8f734df28c1b___NREC_B.Spot 9063_leaf.png → 7.10%
# train/Pepper__bell___Bacterial_spot/45c9c618-5b71-4d9d-a08a-4bd3ceaa0be4___NREC_B.Spot 9178_leaf.png → 3.01%
# train/Pepper__bell___Bacterial_spot/45cfd1ee-052e-43ef-93ff-ae392eedd726___NREC_B.Spot 9084_leaf.png → 16.88%
# train/Pepper__bell___Bacterial_spot/45de9eff-47b2-4e93-941a-11eeedbefc4f___NREC_B.Spot 1945_leaf.png → 5.60%
# train/Pepper__bell___Bacterial_spot/4617631e-a75a-4cd0-a1f5-c06ed41a182a___JR_B.Spot 3281_leaf.png → 7.46%
# train/Pepper__bell___Bacterial_spot/46372226-cfbe-4206-951b-93b8b411d2e7___JR_B.Spot 8890_leaf.png → 8.95%
# train/Pepper__bell___Bacterial_spot/46414704-3483-4a44-b786-6b8ee1814ed7___NREC_B.Spot 9133_leaf.png → 7.67%
# train/Pepper__bell___Bacterial_spot/4683ce17-7653-4718-95a5-7158f3094640___NREC_B.Spot 9196_leaf.png → 6.16%
# train/Pepper__bell___Bacterial_spot/4702d273-50d0-4b7c-b759-7ef62cdb441f___NREC_B.Spot 1828_leaf.png → 15.34%
# train/Pepper__bell___Bacterial_spot/475f941c-242c-42e1-9149-ace60e32b931___NREC_B.Spot 9208_leaf.png → 14.42%
# train/Pepper__bell___Bacterial_spot/4777008f-3144-44df-b230-e94725e711d2___NREC_B.Spot 1979_leaf.png → 7.03%
# train/Pepper__bell___Bacterial_spot/47773ddb-e400-4a5d-87ec-ce711044c31e___NREC_B.Spot 9235_leaf.png → 6.69%
# train/Pepper__bell___Bacterial_spot/47fbd17d-c078-4465-8816-c675abd9c850___JR_B.Spot 3185_leaf.png → 13.11%
# train/Pepper__bell___Bacterial_spot/48a7cf31-19e0-45ba-89c1-7887afa0bdd4___JR_B.Spot 9095_leaf.png → 19.75%
# train/Pepper__bell___Bacterial_spot/490afec2-acdf-4b61-b137-43d43285817c___JR_B.Spot 8949_leaf.png → 11.33%
# train/Pepper__bell___Bacterial_spot/4911efb7-feaf-4602-a028-68b77294c06f___JR_B.Spot 3255_leaf.png → 4.71%
# train/Pepper__bell___Bacterial_spot/4995d36f-321f-4f9e-82c8-9a0c78d1f266___NREC_B.Spot 9076_leaf.png → 4.76%
# train/Pepper__bell___Bacterial_spot/4a18013a-dcd1-4974-b841-89c49b198a11___NREC_B.Spot 1984_leaf.png → 5.92%
# train/Pepper__bell___Bacterial_spot/4a1ba341-501b-4f74-879b-61a9e29a8f9a___NREC_B.Spot 9211_leaf.png → 6.91%
# train/Pepper__bell___Bacterial_spot/4aa16bda-c8f4-40b1-9f68-16bc936e6e9e___JR_B.Spot 3157_leaf.png → 10.99%
# train/Pepper__bell___Bacterial_spot/4b5d5cc8-6df9-4963-8e68-1aaf3e8f2363___JR_B.Spot 3358_leaf.png → 2.59%
# train/Pepper__bell___Bacterial_spot/4bad40b0-af40-4deb-820c-edbcbb9ea372___NREC_B.Spot 1843_leaf.png → 16.85%
# train/Pepper__bell___Bacterial_spot/4c1f3e8b-4c85-4554-b1d7-25feca1f58b3___JR_B.Spot 3250_leaf.png → 6.96%
# train/Pepper__bell___Bacterial_spot/4c2444b0-9bf1-4672-a118-dbde778fdab0___JR_B.Spot 8937_leaf.png → 4.54%
# train/Pepper__bell___Bacterial_spot/4c34e3ed-523a-414d-b28d-52078277cb67___NREC_B.Spot 9174_leaf.png → 3.50%
# train/Pepper__bell___Bacterial_spot/4c664b0a-9ee7-48c2-aaf4-d54e34f5edd3___JR_B.Spot 9060_leaf.png → 13.01%
# train/Pepper__bell___Bacterial_spot/4c6a8199-896f-4cbf-8db4-3baa021a9e1c___NREC_B.Spot 9247_leaf.png → 4.26%
# train/Pepper__bell___Bacterial_spot/4cda1135-6cad-421b-9648-d00f9f3cd16f___JR_B.Spot 3304_leaf.png → 4.68%
# train/Pepper__bell___Bacterial_spot/4cf90b49-1b89-422e-84ae-2e2fcfc2fa02___JR_B.Spot 3362_leaf.png → 4.83%
# train/Pepper__bell___Bacterial_spot/4d035250-f831-438b-a583-d192cbb26a55___JR_B.Spot 3163_leaf.png → 14.24%
# train/Pepper__bell___Bacterial_spot/4d42924a-13e0-4e26-b131-2125e154c542___NREC_B.Spot 9220_leaf.png → 8.40%
# train/Pepper__bell___Bacterial_spot/4d9ffd2f-2740-42f0-9679-c00961ec8f71___NREC_B.Spot 9226_leaf.png → 7.49%
# train/Pepper__bell___Bacterial_spot/4e380ba7-b5dc-46e3-850e-b52a775378d0___NREC_B.Spot 9107_leaf.png → 4.08%
# train/Pepper__bell___Bacterial_spot/4eac0e27-27a7-49ad-80d7-6475aa904154___NREC_B.Spot 1896_leaf.png → 9.23%
# train/Pepper__bell___Bacterial_spot/4f49f8c2-d091-40d0-b85c-db10099b3caa___NREC_B.Spot 9171_leaf.png → 14.56%
# train/Pepper__bell___Bacterial_spot/4f539b76-13f8-43ab-a630-0cc6b1461bc9___JR_B.Spot 3381_leaf.png → 18.19%
# train/Pepper__bell___Bacterial_spot/4fc91e77-fdbc-4041-a510-b267ebbc4bb9___NREC_B.Spot 9055_leaf.png → 4.84%
# train/Pepper__bell___Bacterial_spot/505ac655-cca9-479c-8a2f-35a01b9030cf___JR_B.Spot 8836_leaf.png → 7.77%
# train/Pepper__bell___Bacterial_spot/507d59c4-b6a3-4d94-bbfb-fd763b4033ad___JR_B.Spot 3223_leaf.png → 10.46%
# train/Pepper__bell___Bacterial_spot/50d0c9c6-94ad-46aa-a94f-5a595eb65998___NREC_B.Spot 1946_leaf.png → 11.08%
# train/Pepper__bell___Bacterial_spot/51185964-48e2-493e-a052-42139dd0facd___JR_B.Spot 3331_leaf.png → 7.84%
# train/Pepper__bell___Bacterial_spot/514076ce-e366-4b68-a736-9346cd9a5f61___NREC_B.Spot 9190_leaf.png → 4.52%
# train/Pepper__bell___Bacterial_spot/5149fd50-acad-4a4f-a098-a5378d31479e___NREC_B.Spot 9142_leaf.png → 3.37%
# train/Pepper__bell___Bacterial_spot/517e3352-9e28-4b42-970b-2aa198203960___JR_B.Spot 8855_leaf.png → 6.91%
# train/Pepper__bell___Bacterial_spot/5220d08b-9ead-4c12-9a25-7044d1669d0d___JR_B.Spot 3208_leaf.png → 3.89%
# train/Pepper__bell___Bacterial_spot/525555a6-c09c-4551-8b9d-d2a8050f474d___JR_B.Spot 3355_leaf.png → 4.81%
# train/Pepper__bell___Bacterial_spot/532fab13-878e-4fe9-af94-302ed3e0a906___NREC_B.Spot 1885_leaf.png → 7.21%
# train/Pepper__bell___Bacterial_spot/536247a1-295f-455f-ab45-0798d5efa080___JR_B.Spot 8887_leaf.png → 7.00%
# train/Pepper__bell___Bacterial_spot/5373b361-a0ee-477a-b8e9-f889d062ac1c___JR_B.Spot 3209_leaf.png → 4.60%
# train/Pepper__bell___Bacterial_spot/538ad66b-39cb-4972-8ad7-8ebf1964f782___JR_B.Spot 9001_leaf.png → 7.38%
# train/Pepper__bell___Bacterial_spot/5393f88f-ab0b-4b96-bc56-a76eeb106095___JR_B.Spot 8851_leaf.png → 14.07%
# train/Pepper__bell___Bacterial_spot/539b8a7d-f257-49ff-81b8-76f39b5ac752___NREC_B.Spot 1805_leaf.png → 13.20%
# train/Pepper__bell___Bacterial_spot/5528b2f7-3c8f-4c20-8fdc-5fa996e9a637___JR_B.Spot 3236_leaf.png → 3.67%
# train/Pepper__bell___Bacterial_spot/55724053-6819-47ec-b9e1-84c5be15929e___JR_B.Spot 3205_leaf.png → 3.90%
# train/Pepper__bell___Bacterial_spot/5577c999-dcb2-473a-8455-9972b4ff19ea___NREC_B.Spot 9205_leaf.png → 7.69%
# train/Pepper__bell___Bacterial_spot/557f35cb-b34b-4dc5-959b-efad147d5e88___JR_B.Spot 3382_leaf.png → 22.28%
# train/Pepper__bell___Bacterial_spot/55d4d62f-ed27-4225-8245-c0e732a5a01b___JR_B.Spot 8959_leaf.png → 7.10%
# train/Pepper__bell___Bacterial_spot/560d432a-7524-4482-8b49-1e64767da58b___JR_B.Spot 8831_leaf.png → 8.69%
# train/Pepper__bell___Bacterial_spot/5640520e-087c-41ae-b462-c30d8aa51aab___JR_B.Spot 8914_leaf.png → 5.60%
# train/Pepper__bell___Bacterial_spot/56a3748f-881d-4adb-ab0a-85b5cc6883a9___NREC_B.Spot 9180_leaf.png → 4.11%
# train/Pepper__bell___Bacterial_spot/56c2ec78-14d2-4445-be5d-77a8db483e2a___NREC_B.Spot 1803_leaf.png → 14.30%
# train/Pepper__bell___Bacterial_spot/56d81c17-6145-4887-af27-ea9c6dd64b33___NREC_B.Spot 9068_leaf.png → 13.48%
# train/Pepper__bell___Bacterial_spot/57337b7c-f7b3-4ed0-a249-921df1351cf1___JR_B.Spot 3243_leaf.png → 9.08%
# train/Pepper__bell___Bacterial_spot/57d9d6f1-8f81-4b5b-8985-c82b136a6c4c___JR_B.Spot 8846_leaf.png → 6.03%
# train/Pepper__bell___Bacterial_spot/57ff0455-861f-4f25-9598-c2954ca44027___JR_B.Spot 3115_leaf.png → 9.43%
# train/Pepper__bell___Bacterial_spot/58797902-c466-4226-b913-dcd09c9e026f___NREC_B.Spot 1844_leaf.png → 7.58%
# train/Pepper__bell___Bacterial_spot/58e3b37c-5192-4a03-9f8a-da00330c529a___NREC_B.Spot 9237_leaf.png → 12.29%
# train/Pepper__bell___Bacterial_spot/598fe617-af0b-49c0-ad10-f616bd4e0783___NREC_B.Spot 1847_leaf.png → 7.97%
# train/Pepper__bell___Bacterial_spot/59b6bff9-4aca-4bf4-a129-21179e9cebae___JR_B.Spot 9069_leaf.png → 9.06%
# train/Pepper__bell___Bacterial_spot/5b00e7ef-db0e-43d3-9d4c-db2d8ee2fac3___JR_B.Spot 3360_leaf.png → 2.74%
# train/Pepper__bell___Bacterial_spot/5c421e64-d609-4e2d-9b4f-aa836b4f9864___NREC_B.Spot 1962_leaf.png → 6.48%
# train/Pepper__bell___Bacterial_spot/5c532630-a204-4e10-8fb4-5a0d09f9a1eb___JR_B.Spot 3214_leaf.png → 13.91%
# train/Pepper__bell___Bacterial_spot/5d17a185-67fe-465f-81b9-35d936f24f99___JR_B.Spot 3181_leaf.png → 9.97%
# train/Pepper__bell___Bacterial_spot/5d3a800b-58ed-41f4-ad9a-ad92217a5316___JR_B.Spot 9027_leaf.png → 7.44%
# train/Pepper__bell___Bacterial_spot/5f1731b8-21ee-43d8-a019-8591428f4e3e___JR_B.Spot 9003_leaf.png → 3.85%
# train/Pepper__bell___Bacterial_spot/5f7e373c-1bcb-4730-b55d-d0caf375bb0b___JR_B.Spot 8948_leaf.png → 11.03%
# train/Pepper__bell___Bacterial_spot/6103f8b9-13cd-4a76-a501-33ebe9d24427___JR_B.Spot 8936_leaf.png → 4.26%
# train/Pepper__bell___Bacterial_spot/61764b09-9bb9-44b3-af94-d3408045b7c3___NREC_B.Spot 1891_leaf.png → 18.73%
# train/Pepper__bell___Bacterial_spot/61ec5d27-b456-4164-9bb2-71443e542775___JR_B.Spot 8843_leaf.png → 5.86%
# train/Pepper__bell___Bacterial_spot/61fe0fde-0e1a-4977-adee-e9b66caaf809___NREC_B.Spot 1855_leaf.png → 6.15%
# train/Pepper__bell___Bacterial_spot/6218fa91-d526-4705-aab4-026c328197a3___NREC_B.Spot 9252_leaf.png → 9.69%
# train/Pepper__bell___Bacterial_spot/62ff339a-6883-4d8f-b7e3-913c1b950c38___JR_B.Spot 3347_leaf.png → 5.22%
# train/Pepper__bell___Bacterial_spot/64367d1d-8954-432d-94bf-9ee75a812a85___NREC_B.Spot 1890_leaf.png → 4.72%
# train/Pepper__bell___Bacterial_spot/644b37d1-495a-40ef-9cff-163a97016d71___JR_B.Spot 3269_leaf.png → 4.32%
# train/Pepper__bell___Bacterial_spot/648a0b23-8a55-4530-a0a0-b04882298d24___NREC_B.Spot 1839_leaf.png → 9.64%
# train/Pepper__bell___Bacterial_spot/64c23fb9-51a0-4690-bed5-47ab3af8c294___JR_B.Spot 9072_leaf.png → 3.95%
# train/Pepper__bell___Bacterial_spot/64ed4b17-84ad-4088-b079-c02eceef5e7e___NREC_B.Spot 1958_leaf.png → 22.50%
# train/Pepper__bell___Bacterial_spot/64f4dcf0-30b4-41b2-b5e6-6e6798c3202d___JR_B.Spot 8834_leaf.png → 12.60%
# train/Pepper__bell___Bacterial_spot/656dbf3a-3aee-46a5-80b9-a86953fc82c5___JR_B.Spot 8879_leaf.png → 7.78%
# train/Pepper__bell___Bacterial_spot/65a84ec0-79dc-4ae3-bfce-81c3f4b50a08___JR_B.Spot 8858_leaf.png → 8.72%
# train/Pepper__bell___Bacterial_spot/65c3a8f9-9631-4b86-9ae3-28116c869247___JR_B.Spot 9005_leaf.png → 4.29%
# train/Pepper__bell___Bacterial_spot/65de6d37-4ea5-4ac7-af08-a974eb5b501a___NREC_B.Spot 9106_leaf.png → 4.19%
# train/Pepper__bell___Bacterial_spot/65fc5138-b38a-42d6-a892-1441585ceebd___NREC_B.Spot 9057_leaf.png → 3.76%
# train/Pepper__bell___Bacterial_spot/665fd560-82b6-4af9-8f0a-0dbace910cb2___JR_B.Spot 9062_leaf.png → 9.57%
# train/Pepper__bell___Bacterial_spot/66d4cd59-bc59-49cc-9a94-dafa07318fb4___JR_B.Spot 8975_leaf.png → 4.15%
# train/Pepper__bell___Bacterial_spot/66dc5b26-4643-4c8b-a95b-d273ead3672b___JR_B.Spot 3191_leaf.png → 13.62%
# train/Pepper__bell___Bacterial_spot/67b4af5b-0ca1-4e11-a7c1-179b4defa8fc___JR_B.Spot 8965_leaf.png → 10.13%
# train/Pepper__bell___Bacterial_spot/67e58468-8546-4324-8e1e-ae10abf2cb5b___JR_B.Spot 9099_leaf.png → 15.11%
# train/Pepper__bell___Bacterial_spot/67fb9590-9c1b-47f0-b5e2-f7377136bcba___NREC_B.Spot 1845_leaf.png → 7.81%
# train/Pepper__bell___Bacterial_spot/6820b823-5ed9-422d-ba0c-5134cd046588___JR_B.Spot 9049_leaf.png → 8.89%
# train/Pepper__bell___Bacterial_spot/691dd132-7f59-4494-873c-a9dc69331c60___JR_B.Spot 3390_leaf.png → 9.11%
# train/Pepper__bell___Bacterial_spot/692729b9-8d2b-49a7-ac16-ce892964d91b___JR_B.Spot 3140_leaf.png → 14.67%
# train/Pepper__bell___Bacterial_spot/697e19e9-b11b-4bc8-884b-e25d432b90f6___NREC_B.Spot 9206_leaf.png → 9.14%
# train/Pepper__bell___Bacterial_spot/69e109a9-8cfb-427e-8e3c-f327edb59164___JR_B.Spot 9081_leaf.png → 12.83%
# train/Pepper__bell___Bacterial_spot/6a0e3916-d415-42ca-936b-8648ef702ea9___NREC_B.Spot 9179_leaf.png → 5.01%
# train/Pepper__bell___Bacterial_spot/6a457821-e634-425c-90f0-a4bbd76b5722___JR_B.Spot 3159_leaf.png → 10.79%
# train/Pepper__bell___Bacterial_spot/6b1b260e-fab5-4a73-936c-5592119c13fe___NREC_B.Spot 1952_leaf.png → 8.98%
# train/Pepper__bell___Bacterial_spot/6b645d69-0103-40e0-b459-9cdf2ef888e7___JR_B.Spot 3253_leaf.png → 5.01%
# train/Pepper__bell___Bacterial_spot/6b8b1a3d-4dd3-42a3-bebb-062d43d45a34___NREC_B.Spot 9204_leaf.png → 3.07%
# train/Pepper__bell___Bacterial_spot/6c475c34-fcf6-4386-97f3-a08424dc0401___NREC_B.Spot 1801_leaf.png → 5.68%
# train/Pepper__bell___Bacterial_spot/6cb54c8d-be3e-48d1-a6ac-08eeb93d6201___JR_B.Spot 3401_leaf.png → 10.78%
# train/Pepper__bell___Bacterial_spot/6ceb56c6-36aa-4196-b60f-6fb8306b3cb4___NREC_B.Spot 9162_leaf.png → 5.32%
# train/Pepper__bell___Bacterial_spot/6cfc68b9-20d0-4a6c-ac75-16404a37a070___JR_B.Spot 3178_leaf.png → 5.93%
# train/Pepper__bell___Bacterial_spot/6d15afc9-3066-4ce4-811c-97da31711bf3___NREC_B.Spot 9157_leaf.png → 6.82%
# train/Pepper__bell___Bacterial_spot/6d21b1fe-9e5d-4586-9726-14844ad5116f___JR_B.Spot 3120_leaf.png → 9.68%
# train/Pepper__bell___Bacterial_spot/6e1e07ba-212d-4494-b8bf-73d12d720c20___JR_B.Spot 3392_leaf.png → 6.51%
# train/Pepper__bell___Bacterial_spot/6e41a639-da20-44dd-bcd4-baafc498f163___NREC_B.Spot 1934_leaf.png → 10.41%
# train/Pepper__bell___Bacterial_spot/6e698a9c-27ae-4ebb-a041-c8f06a69d664___JR_B.Spot 3133_leaf.png → 6.51%
# train/Pepper__bell___Bacterial_spot/6e789f9f-96b0-4221-9755-a75ca579def7___NREC_B.Spot 1795_leaf.png → 12.34%
# train/Pepper__bell___Bacterial_spot/6ea47428-2b33-473f-be41-a775ca04958f___NREC_B.Spot 9231_leaf.png → 3.92%
# train/Pepper__bell___Bacterial_spot/6fc860ea-46cd-4b40-8d53-27c1ebf95935___NREC_B.Spot 1836_leaf.png → 8.81%
# train/Pepper__bell___Bacterial_spot/701d7213-d2ab-4797-8709-102c69d7ab5d___JR_B.Spot 3312_leaf.png → 3.60%
# train/Pepper__bell___Bacterial_spot/7081e6ab-4d18-4b97-9cf5-86c6adaa4715___JR_B.Spot 3189_leaf.png → 12.56%
# train/Pepper__bell___Bacterial_spot/70985466-254f-479b-86f2-9792be0864ed___JR_B.Spot 9044_leaf.png → 7.32%
# train/Pepper__bell___Bacterial_spot/718cf35c-8f3b-4d29-9c49-0aac5a8b6660___NREC_B.Spot 9098_leaf.png → 8.12%
# train/Pepper__bell___Bacterial_spot/71910a98-a735-4f6d-bd6b-117845ed0ad6___JR_B.Spot 3282_leaf.png → 9.07%
# train/Pepper__bell___Bacterial_spot/731d3112-8dfa-4ce0-b27e-6a0cdb661a6d___NREC_B.Spot 9232_leaf.png → 6.64%
# train/Pepper__bell___Bacterial_spot/73ef1d83-6ac0-4955-938a-fca94432814b___JR_B.Spot 3148_leaf.png → 14.12%
# train/Pepper__bell___Bacterial_spot/740389fb-026a-45f3-ab93-716987328da0___JR_B.Spot 8905_leaf.png → 8.28%
# train/Pepper__bell___Bacterial_spot/75a64b98-63dd-4ef1-907f-09bdeb3a89dc___JR_B.Spot 3228_leaf.png → 8.61%
# train/Pepper__bell___Bacterial_spot/75faa1f4-e20f-4bb2-811f-9cbd757c652c___JR_B.Spot 9006_leaf.png → 4.44%
# train/Pepper__bell___Bacterial_spot/7642e377-d6af-4092-ae84-a1fa10a7f1e1___NREC_B.Spot 1914_leaf.png → 3.73%
# train/Pepper__bell___Bacterial_spot/77025edb-ef4e-4a72-a8d8-f4c12d43d91c___NREC_B.Spot 9083_leaf.png → 6.19%
# train/Pepper__bell___Bacterial_spot/77d6d18a-0f6c-4417-80c6-42c0c9e7a83d___NREC_B.Spot 9147_leaf.png → 13.02%
# train/Pepper__bell___Bacterial_spot/78bed62c-8645-4956-a9c0-c6709e254a43___JR_B.Spot 3099_leaf.png → 10.14%
# train/Pepper__bell___Bacterial_spot/78c2d8fb-65cc-4d1b-9524-d904c87cbe99___NREC_B.Spot 1829_leaf.png → 21.26%
# train/Pepper__bell___Bacterial_spot/78cbd7cf-98fb-41f1-ae32-6655c02fa49c___JR_B.Spot 3292_leaf.png → 6.16%
# train/Pepper__bell___Bacterial_spot/78dbe7fe-0821-4c19-922f-0e330f0cd3bd___JR_B.Spot 8856_leaf.png → 4.77%
# train/Pepper__bell___Bacterial_spot/79264de2-10b4-4b3d-a3fe-42916a666bcb___NREC_B.Spot 9239_leaf.png → 11.07%
# train/Pepper__bell___Bacterial_spot/794eb318-4b89-4774-89af-76131cf7b793___NREC_B.Spot 1920_leaf.png → 2.77%
# train/Pepper__bell___Bacterial_spot/795a0fc6-b2cc-41b8-b42b-88ce395b4186___NREC_B.Spot 1937_leaf.png → 9.04%
# train/Pepper__bell___Bacterial_spot/7972395e-d2f0-4cf8-a4b5-ac4ca91d4a6e___JR_B.Spot 9075_leaf.png → 5.15%
# train/Pepper__bell___Bacterial_spot/799cf6ba-63c7-442c-b33a-4b1d31b00eac___NREC_B.Spot 1852_leaf.png → 11.05%
# train/Pepper__bell___Bacterial_spot/79aa6f93-2261-4e77-a452-c6d09f836ba3___JR_B.Spot 3126_leaf.png → 8.68%
# train/Pepper__bell___Bacterial_spot/7a77bf9c-a881-49bd-9bcf-a3fae89788b1___NREC_B.Spot 1793_leaf.png → 5.78%
# train/Pepper__bell___Bacterial_spot/7aebe4e4-237e-46b0-9c0d-fc3bd9ba11c3___NREC_B.Spot 9132_leaf.png → 5.27%
# train/Pepper__bell___Bacterial_spot/7b174b14-e48d-4448-a62a-cce6a6ae96f3___NREC_B.Spot 9187_leaf.png → 7.66%
# train/Pepper__bell___Bacterial_spot/7b21dafb-0173-4762-8fb5-8bb9b0aa604c___JR_B.Spot 3149_leaf.png → 15.64%
# train/Pepper__bell___Bacterial_spot/7b3f4992-f771-4b6e-b25f-7ec4c5823c88___JR_B.Spot 8951_leaf.png → 6.16%
# train/Pepper__bell___Bacterial_spot/7b499cbf-4eb9-4ce8-8aaf-ad09313ec315___NREC_B.Spot 1817_leaf.png → 3.84%
# train/Pepper__bell___Bacterial_spot/7b7b589f-1bb8-43fb-8fa0-b510e200dd99___JR_B.Spot 9061_leaf.png → 20.34%
# train/Pepper__bell___Bacterial_spot/7b986a8d-5bc9-4cad-a225-f25bfd7ef289___JR_B.Spot 3233_leaf.png → 9.60%
# train/Pepper__bell___Bacterial_spot/7beb562a-e1b0-40a2-8b44-fd892051da87___JR_B.Spot 8989_leaf.png → 4.84%
# train/Pepper__bell___Bacterial_spot/7cca52ca-c5bb-4670-aa24-c956c828db39___JR_B.Spot 8982_leaf.png → 10.86%
# train/Pepper__bell___Bacterial_spot/7cff0c53-dc4b-4d5f-ade4-0fb2177c3ccb___NREC_B.Spot 9079_leaf.png → 3.33%
# train/Pepper__bell___Bacterial_spot/7e08147f-d930-4854-a1de-300e53834534___JR_B.Spot 3127_leaf.png → 6.55%
# train/Pepper__bell___Bacterial_spot/7f07dc8d-dc42-4b4a-89a8-f2d2e10bdba7___NREC_B.Spot 9167_leaf.png → 5.86%
# train/Pepper__bell___Bacterial_spot/7f4db70a-2dca-4c7d-867b-a3827e89994f___NREC_B.Spot 9172_leaf.png → 4.79%
# train/Pepper__bell___Bacterial_spot/7f9fc159-4db8-4e64-93eb-47e1f323d981___JR_B.Spot 8872_leaf.png → 4.60%
# train/Pepper__bell___Bacterial_spot/7fb4d5d5-e4c8-42d1-b1a0-c2ee6abda2d3___NREC_B.Spot 1787_leaf.png → 8.74%
# train/Pepper__bell___Bacterial_spot/7fb9aaff-6871-44f7-8957-e0c05fee5e2d___NREC_B.Spot 9140_leaf.png → 12.31%
# train/Pepper__bell___Bacterial_spot/8048788f-facf-475b-8728-4724d98f4df9___JR_B.Spot 3216_leaf.png → 15.77%
# train/Pepper__bell___Bacterial_spot/80d302d6-102c-4fe0-acf8-8ff5b796767e___JR_B.Spot 8898_leaf.png → 9.66%
# train/Pepper__bell___Bacterial_spot/816dee9f-b43f-42da-b0c9-3fb8b29d511d___NREC_B.Spot 9182_leaf.png → 12.57%
# train/Pepper__bell___Bacterial_spot/820a7257-dc1d-46af-ba5a-b006c35fc1b1___JR_B.Spot 3116_leaf.png → 1.48%
# train/Pepper__bell___Bacterial_spot/821fa2f8-b221-472d-a789-f0c42923f52a___JR_B.Spot 9046_leaf.png → 8.01%
# train/Pepper__bell___Bacterial_spot/8289c053-a0c4-4740-9fd8-fd316b6f5688___JR_B.Spot 3299_leaf.png → 8.73%
# train/Pepper__bell___Bacterial_spot/8295d0d3-a2b8-4f32-ac02-7e0ee8f75406___NREC_B.Spot 1790_leaf.png → 10.01%
# train/Pepper__bell___Bacterial_spot/82b9fdcc-3000-46fe-b955-063e77dd5968___JR_B.Spot 3324_leaf.png → 2.80%
# train/Pepper__bell___Bacterial_spot/831d19a0-117e-477c-9301-d9279edd1c5d___JR_B.Spot 3343_leaf.png → 4.02%
# train/Pepper__bell___Bacterial_spot/8344bdaa-cb73-4046-bdc0-4657564ccef8___JR_B.Spot 3170_leaf.png → 11.09%
# train/Pepper__bell___Bacterial_spot/836b4b9e-85d5-47bc-ad93-9ab31b07be3d___JR_B.Spot 3361_leaf.png → 4.33%
# train/Pepper__bell___Bacterial_spot/83876bfd-572a-461f-b801-303483f2a21a___JR_B.Spot 8880_leaf.png → 6.74%
# train/Pepper__bell___Bacterial_spot/8429c476-0b37-4e58-b614-c3fc59f4cd0c___NREC_B.Spot 9089_leaf.png → 4.85%
# train/Pepper__bell___Bacterial_spot/8465e92e-0f86-4792-be92-5f5642e8b61b___NREC_B.Spot 1898_leaf.png → 7.51%
# train/Pepper__bell___Bacterial_spot/8485adde-4e43-4c10-a9b1-be320de27869___NREC_B.Spot 9164_leaf.png → 7.59%
# train/Pepper__bell___Bacterial_spot/84c56927-7b27-4cc8-88d1-d4cd544cabe4___NREC_B.Spot 9185_leaf.png → 7.36%
# train/Pepper__bell___Bacterial_spot/84d20d35-2bd6-4bab-aa96-d4dcc402dcf0___NREC_B.Spot 9228_leaf.png → 12.66%
# train/Pepper__bell___Bacterial_spot/84e67357-edd8-445d-9c49-32b1c5d5deeb___JR_B.Spot 8921_leaf.png → 14.13%
# train/Pepper__bell___Bacterial_spot/84f03e83-ac3b-4804-8791-68b2a523b065___NREC_B.Spot 1870_leaf.png → 5.78%
# train/Pepper__bell___Bacterial_spot/8581fc41-9bd8-4845-9eef-bf1c58997a37___JR_B.Spot 9038_leaf.png → 7.85%
# train/Pepper__bell___Bacterial_spot/858e8261-f962-4ce6-825c-d498e24e957c___JR_B.Spot 3273_leaf.png → 14.81%
# train/Pepper__bell___Bacterial_spot/8695a15f-cdb4-444f-817b-7f4fc22a7a7a___NREC_B.Spot 9230_leaf.png → 3.09%
# train/Pepper__bell___Bacterial_spot/86ef217d-b405-48b5-9cb0-cfaf47f61b15___NREC_B.Spot 9088_leaf.png → 7.13%
# train/Pepper__bell___Bacterial_spot/875f41e8-cd70-44f4-a17c-c8b77fed406c___JR_B.Spot 8902_leaf.png → 9.06%
# train/Pepper__bell___Bacterial_spot/87606a4a-7b9b-404f-af47-2cd43498d8a2___NREC_B.Spot 1924_leaf.png → 10.06%
# train/Pepper__bell___Bacterial_spot/884c2da1-3b43-46aa-85bb-0f72ed25c266___JR_B.Spot 8906_leaf.png → 13.72%
# train/Pepper__bell___Bacterial_spot/8860c32a-65de-4346-9ccb-c9d78588805b___JR_B.Spot 3194_leaf.png → 13.65%
# train/Pepper__bell___Bacterial_spot/88a00319-c477-422b-bc43-91d03382f8c7___JR_B.Spot 3402_leaf.png → 10.66%
# train/Pepper__bell___Bacterial_spot/895a07dd-367e-4e79-8730-27bec5d951e9___JR_B.Spot 3259_leaf.png → 2.44%
# train/Pepper__bell___Bacterial_spot/8a76c7e0-7da2-41c0-8167-75da69445d0d___JR_B.Spot 3143_leaf.png → 11.18%
# train/Pepper__bell___Bacterial_spot/8a9bc15a-fd14-44ac-b8eb-37ea8a209406___NREC_B.Spot 1819_leaf.png → 6.65%
# train/Pepper__bell___Bacterial_spot/8b50f2db-cbf2-4758-bea6-a011f0cc1497___JR_B.Spot 3235_leaf.png → 8.62%
# train/Pepper__bell___Bacterial_spot/8c7fe94d-5e80-4849-a92c-715d3aaf02a3___JR_B.Spot 3218_leaf.png → 15.88%
# train/Pepper__bell___Bacterial_spot/8c9e49b1-c4ee-402e-b31b-a7b33e887d0c___JR_B.Spot 3313_leaf.png → 5.23%
# train/Pepper__bell___Bacterial_spot/8d8df238-9cd0-42b2-bd0f-46ada2ad1798___JR_B.Spot 8927_leaf.png → 10.58%
# train/Pepper__bell___Bacterial_spot/8f9dedbd-e4c2-4bbb-b9c4-efb8d61bddc2___NREC_B.Spot 1882_leaf.png → 10.43%
# train/Pepper__bell___Bacterial_spot/9023d324-f287-41ab-801b-27cc9a4ee9d5___JR_B.Spot 8981_leaf.png → 11.75%
# train/Pepper__bell___Bacterial_spot/9029703b-db1b-4227-bd29-ab05cc53b7ba___NREC_B.Spot 1802_leaf.png → 12.32%
# train/Pepper__bell___Bacterial_spot/9184edd2-6056-4da1-aaeb-bc9dc92d5247___NREC_B.Spot 9155_leaf.png → 4.38%
# train/Pepper__bell___Bacterial_spot/91b84b7f-2132-4d72-897b-95c763ce5397___JR_B.Spot 9067_leaf.png → 10.87%
# train/Pepper__bell___Bacterial_spot/91d5631f-83d9-467b-b5f3-48e408594225___NREC_B.Spot 9129_leaf.png → 5.21%
# train/Pepper__bell___Bacterial_spot/92539ab8-1ccd-43c8-8b1a-d734a031eb5a___JR_B.Spot 3186_leaf.png → 12.24%
# train/Pepper__bell___Bacterial_spot/937f93b6-2ecd-4129-9995-e0473d498335___NREC_B.Spot 9045_leaf.png → 9.97%
# train/Pepper__bell___Bacterial_spot/9435d4a5-e198-4c46-8a90-a888cb2e7267___JR_B.Spot 3316_leaf.png → 4.87%
# train/Pepper__bell___Bacterial_spot/948bc0e0-8552-426a-898f-270b9573c28f___NREC_B.Spot 9062_leaf.png → 8.17%
# train/Pepper__bell___Bacterial_spot/94b1fbe4-4a9d-4237-a6ca-41a6db87d654___JR_B.Spot 3242_leaf.png → 8.56%
# train/Pepper__bell___Bacterial_spot/94c2cf91-17c3-4ee1-b8f2-b20103e1c14f___NREC_B.Spot 9094_leaf.png → 5.07%
# train/Pepper__bell___Bacterial_spot/94f00ecd-184d-40ee-a7e9-d6feb19402cb___JR_B.Spot 8957_leaf.png → 4.46%
# train/Pepper__bell___Bacterial_spot/95238fdb-d39b-40cb-b644-143e66befcc1___JR_B.Spot 3151_leaf.png → 11.54%
# train/Pepper__bell___Bacterial_spot/952535f2-d337-434c-90e4-0be62ad20db9___JR_B.Spot 3348_leaf.png → 3.98%
# train/Pepper__bell___Bacterial_spot/952824e6-01bc-4b00-b893-18546066d084___NREC_B.Spot 9246_leaf.png → 4.27%
# train/Pepper__bell___Bacterial_spot/95846c59-3b47-477f-93f1-4f857099be3d___NREC_B.Spot 9203_leaf.png → 2.10%
# train/Pepper__bell___Bacterial_spot/95acdbc4-f47e-445b-9dca-f194911f9cb3___JR_B.Spot 3283_leaf.png → 11.37%
# train/Pepper__bell___Bacterial_spot/968ac529-2487-4400-b495-423d49d69831___NREC_B.Spot 9238_leaf.png → 10.52%
# train/Pepper__bell___Bacterial_spot/96924079-4bc2-46f0-8eee-1e7e06bf559a___JR_B.Spot 3279_leaf.png → 4.67%
# train/Pepper__bell___Bacterial_spot/969f1458-b7a9-4880-9759-05b0005c978e___JR_B.Spot 8978_leaf.png → 5.16%
# train/Pepper__bell___Bacterial_spot/96f532cf-0f68-421f-824e-4bc6e1dc6925___JR_B.Spot 3168_leaf.png → 11.86%
# train/Pepper__bell___Bacterial_spot/9728896c-149f-415b-86b3-ef5b95dd9143___JR_B.Spot 8862_leaf.png → 5.69%
# train/Pepper__bell___Bacterial_spot/975b25df-a4d7-4aca-b1b9-312487544eaa___JR_B.Spot 8830_leaf.png → 7.68%
# train/Pepper__bell___Bacterial_spot/976a6621-9c5a-4c7b-a045-fdceff04d081___JR_B.Spot 3108_leaf.png → 11.94%
# train/Pepper__bell___Bacterial_spot/97b1492e-13ef-44f3-aa9d-de01444499db___JR_B.Spot 3219_leaf.png → 15.22%
# train/Pepper__bell___Bacterial_spot/97fa8b63-1a92-4760-802c-2acfecc67e65___JR_B.Spot 8827_leaf.png → 11.74%
# ...
# test/Tomato_Bacterial_spot/a9f9ac3b-84be-4356-9a00-12beaea27593___GCREC_Bact.Sp 3638_leaf.png → 11.79%
# test/Tomato_Bacterial_spot/acbc36cd-9c39-419b-95da-7858806a063a___GCREC_Bact.Sp 3811_leaf.png → 12.56%
# test/Tomato_Bacterial_spot/ae7425b4-aaae-44e0-ae8e-19623a66ed70___GCREC_Bact.Sp 2958_leaf.png → 13.82%
# test/Tomato_Bacterial_spot/af4af498-b222-49db-ac1a-e9a546b69dd6___GCREC_Bact.Sp 3003_leaf.png → 4.30%
# test/Tomato_Bacterial_spot/aff5e486-cb79-4e8d-8285-c4c98d909beb___GCREC_Bact.Sp 6120_leaf.png → 6.19%
# test/Tomato_Bacterial_spot/b1dd4d7d-40ab-40bc-8246-5dabfac9dbd9___GCREC_Bact.Sp 3488_leaf.png → 6.18%
# test/Tomato_Bacterial_spot/b39d9edd-bcee-456c-b078-e3e286171114___GCREC_Bact.Sp 3656_leaf.png → 10.16%
# test/Tomato_Bacterial_spot/b3c9f756-9328-46de-989b-a75859b40027___GCREC_Bact.Sp 3403_leaf.png → 11.29%
# test/Tomato_Bacterial_spot/b71909d5-1354-4730-abdd-504679c558be___GCREC_Bact.Sp 5944_leaf.png → 6.41%
# test/Tomato_Bacterial_spot/b8eae33d-0b5a-45c0-a926-001512a72db1___UF.GRC_BS_Lab Leaf 0611_leaf.png → 13.22%
# test/Tomato_Bacterial_spot/b90cb55e-b1fb-47b5-90f9-543845814e68___GCREC_Bact.Sp 6029_leaf.png → 13.38%
# test/Tomato_Bacterial_spot/bac40427-ce12-4369-8866-9e48e2f982da___GCREC_Bact.Sp 6092_leaf.png → 12.12%
# test/Tomato_Bacterial_spot/bc185bd9-5335-4fd5-b426-8c30b56feda3___UF.GRC_BS_Lab Leaf 8782_leaf.png → 9.76%
# test/Tomato_Bacterial_spot/bcd94233-e103-4604-8c04-67177af3c7e0___GCREC_Bact.Sp 6233_leaf.png → 11.42%
# test/Tomato_Bacterial_spot/bd7ff95f-02e5-491a-8bf9-5f2ac2277e7c___UF.GRC_BS_Lab Leaf 0932_leaf.png → 18.63%
# test/Tomato_Bacterial_spot/c04f4774-dbfd-4ab0-98fd-437759b1b7f7___UF.GRC_BS_Lab Leaf 9114_leaf.png → 45.50%
# test/Tomato_Bacterial_spot/c0e3fc41-4d61-4a2d-a1e0-f5d658803182___GCREC_Bact.Sp 5975_leaf.png → 6.07%
# test/Tomato_Bacterial_spot/c0f90bbb-d9ac-4ed6-9e3c-296c17ce42a2___GCREC_Bact.Sp 3808_leaf.png → 5.57%
# test/Tomato_Bacterial_spot/c3611ed0-7bb3-47cd-bfac-86cd6f44b5ef___UF.GRC_BS_Lab Leaf 0979_leaf.png → 18.06%
# test/Tomato_Bacterial_spot/c37d3b8a-fecc-488a-ab78-c00f5240283c___GCREC_Bact.Sp 3343_leaf.png → 6.05%
# test/Tomato_Bacterial_spot/c3d68df9-2312-4b85-8d14-47b06fe5d0d8___UF.GRC_BS_Lab Leaf 0374_leaf.png → 9.68%
# test/Tomato_Bacterial_spot/c3f278c8-3bf4-4837-91f1-2723a99a22d8___GCREC_Bact.Sp 6359_leaf.png → 7.98%
# test/Tomato_Bacterial_spot/c4b6fcb3-faa3-40ce-b3de-9687301e20c6___GCREC_Bact.Sp 6261_leaf.png → 14.55%
# test/Tomato_Bacterial_spot/c53b64d9-37ef-4269-b809-00e59c2a033f___GCREC_Bact.Sp 3337_leaf.png → 8.76%
# test/Tomato_Bacterial_spot/c6492dd1-0d2e-4d57-85cc-3544734a8125___UF.GRC_BS_Lab Leaf 8646_leaf.png → 14.13%
# test/Tomato_Bacterial_spot/c9c0a326-c094-4cea-94cb-bc240bb3be23___GCREC_Bact.Sp 3652_leaf.png → 7.66%
# test/Tomato_Bacterial_spot/caf5fa98-1dd1-44a8-8ce1-35fff6e06818___GCREC_Bact.Sp 5783_leaf.png → 14.07%
# test/Tomato_Bacterial_spot/cd36ac93-df2b-41f4-b29e-dd0be47114b7___GCREC_Bact.Sp 3674_leaf.png → 11.04%
# test/Tomato_Bacterial_spot/ce71eb1e-cf9d-465b-adc2-15eb07c9e687___GCREC_Bact.Sp 3394_leaf.png → 11.11%
# test/Tomato_Bacterial_spot/cf155207-09bc-454e-a31b-0d469c9bb3d7___GCREC_Bact.Sp 2989_leaf.png → 7.76%
# test/Tomato_Bacterial_spot/d0afa6c0-1ed2-4c53-bf88-a15ed11ed800___GCREC_Bact.Sp 3742_leaf.png → 8.34%
# test/Tomato_Bacterial_spot/d0ce6851-bf97-4410-94f3-ccdcddd2a0fe___GCREC_Bact.Sp 3424_leaf.png → 10.93%
# test/Tomato_Bacterial_spot/d1c0694d-0c25-41bf-9f19-64487795d52c___GCREC_Bact.Sp 5567_leaf.png → 9.77%
# test/Tomato_Bacterial_spot/d2baf547-f447-4b60-b642-7e1008ac6187___GCREC_Bact.Sp 5920_leaf.png → 12.86%
# test/Tomato_Bacterial_spot/d374d0c5-2a5c-4d5e-afc6-0410d91c9d55___GCREC_Bact.Sp 6321_leaf.png → 9.16%
# test/Tomato_Bacterial_spot/d47b18fc-8e90-478a-ae2b-c9974b0edc80___GCREC_Bact.Sp 3222_leaf.png → 9.25%
# test/Tomato_Bacterial_spot/d4f3d9f0-b02e-4632-bf9d-6aefdcd4bae3___GCREC_Bact.Sp 3843_leaf.png → 8.71%
# test/Tomato_Bacterial_spot/d5291fc4-6702-407a-a09f-1c8e2e7455fc___GCREC_Bact.Sp 5642_leaf.png → 11.16%
# test/Tomato_Bacterial_spot/d581dfed-7057-4f0b-8417-5725beb0168e___UF.GRC_BS_Lab Leaf 0259_leaf.png → 34.94%
# test/Tomato_Bacterial_spot/d5b68019-d730-432d-80b5-dcd87b39742d___UF.GRC_BS_Lab Leaf 1200_leaf.png → 19.91%
# test/Tomato_Bacterial_spot/d60ef655-b54e-4e58-ab25-64f523a97694___GCREC_Bact.Sp 3336_leaf.png → 8.36%
# test/Tomato_Bacterial_spot/d64951f4-a447-44c7-80b7-1143a6e4a4e8___UF.GRC_BS_Lab Leaf 9190_leaf.png → 7.93%
# test/Tomato_Bacterial_spot/d8d99dae-78a8-46f4-b7ad-600e0685d592___GCREC_Bact.Sp 6136_leaf.png → 10.47%
# test/Tomato_Bacterial_spot/d8e40874-f16d-43e2-9922-97a973861a0c___UF.GRC_BS_Lab Leaf 8728_leaf.png → 6.85%
# test/Tomato_Bacterial_spot/d91864c6-22e4-4dea-b10f-e64061a300a3___GCREC_Bact.Sp 3572_leaf.png → 5.04%
# test/Tomato_Bacterial_spot/d96166b8-e301-4613-adbb-66eb792a16b6___GCREC_Bact.Sp 3792_leaf.png → 7.30%
# test/Tomato_Bacterial_spot/d9a42de4-b5ee-4464-a369-bc7ba9d9ebab___GCREC_Bact.Sp 3328_leaf.png → 30.64%
# test/Tomato_Bacterial_spot/da866ac6-4fcc-4722-8cf6-3d0d93011d65___GCREC_Bact.Sp 3550_leaf.png → 8.98%
# test/Tomato_Bacterial_spot/dabf464f-af7f-4fdb-b598-ebc369968706___GCREC_Bact.Sp 3287_leaf.png → 8.94%
# test/Tomato_Bacterial_spot/dbabca53-fd46-46e9-91c0-64232aac8c25___GCREC_Bact.Sp 3816_leaf.png → 9.08%
# test/Tomato_Bacterial_spot/dc206acc-605b-4a85-a35b-44ce62f0ea7e___GCREC_Bact.Sp 6055_leaf.png → 8.08%
# test/Tomato_Bacterial_spot/dc865b07-0701-4ddd-be52-cc75f80d0ada___UF.GRC_BS_Lab Leaf 0683_leaf.png → 24.91%
# test/Tomato_Bacterial_spot/dddde2e7-7228-47c6-a263-e1c5003471c0___GCREC_Bact.Sp 3512_leaf.png → 9.72%
# test/Tomato_Bacterial_spot/de0d63c7-a1a2-43e0-9316-44381a5cb46a___GCREC_Bact.Sp 3858_leaf.png → 14.16%
# test/Tomato_Bacterial_spot/de5c0550-5f5a-4148-9fa1-a3d52b9ec811___UF.GRC_BS_Lab Leaf 0660_leaf.png → 15.43%
# test/Tomato_Bacterial_spot/deafaefa-dc4f-40ab-b26a-f462d334e8b2___GCREC_Bact.Sp 3300_leaf.png → 13.60%
# test/Tomato_Bacterial_spot/dfc16b5b-67c4-4725-982f-c7282f514b38___GCREC_Bact.Sp 3100_leaf.png → 14.33%
# test/Tomato_Bacterial_spot/e2c80b64-2520-49c4-bedc-a604355be09b___GCREC_Bact.Sp 3609_leaf.png → 6.94%
# test/Tomato_Bacterial_spot/e5ab7644-032a-44d8-97dd-3e9eec19278b___GCREC_Bact.Sp 6208_leaf.png → 16.42%
# test/Tomato_Bacterial_spot/e7545c08-3299-4f70-b9bb-3fb57c539f5d___UF.GRC_BS_Lab Leaf 9162_leaf.png → 19.68%
# test/Tomato_Bacterial_spot/e7dc7765-74e9-4cd8-94f1-a585c41bea16___GCREC_Bact.Sp 3267_leaf.png → 13.13%
# test/Tomato_Bacterial_spot/e928ca07-1757-4734-a146-b18176167cf9___GCREC_Bact.Sp 3709_leaf.png → 24.96%
# test/Tomato_Bacterial_spot/e98fdfc0-1871-4b7d-b32a-35731e973289___GCREC_Bact.Sp 5834_leaf.png → 9.38%
# test/Tomato_Bacterial_spot/ea5451fc-7d10-4a88-8193-cbbdb1f8f748___GCREC_Bact.Sp 3785_leaf.png → 5.99%
# test/Tomato_Bacterial_spot/eb24be78-376c-4a25-a738-0abb052b01cb___UF.GRC_BS_Lab Leaf 8957_leaf.png → 15.70%
# test/Tomato_Bacterial_spot/eb69cd1d-ab61-44cf-b8d0-2e6317fd3043___GCREC_Bact.Sp 2998_leaf.png → 10.89%
# test/Tomato_Bacterial_spot/eba8000b-ecbc-4417-bc21-67c7e4dd8c8d___GCREC_Bact.Sp 5916_leaf.png → 13.75%
# test/Tomato_Bacterial_spot/ebaf3d67-cb6b-4b01-be28-f2276db98177___GCREC_Bact.Sp 3649_leaf.png → 8.29%
# test/Tomato_Bacterial_spot/ec7eb8ff-d779-4fae-a230-aa65a93508a3___GCREC_Bact.Sp 5927_leaf.png → 14.59%
# test/Tomato_Bacterial_spot/ec86d98d-7fb3-43e9-addb-3686492e5ab9___GCREC_Bact.Sp 3731_leaf.png → 7.66%
# test/Tomato_Bacterial_spot/ed72f0b8-cd69-41fd-99a8-ae792c6fa16f___GCREC_Bact.Sp 3186_leaf.png → 11.45%
# test/Tomato_Bacterial_spot/edcbb73e-46f6-4798-bcdd-7c4477b6b9cf___GCREC_Bact.Sp 3214_leaf.png → 6.51%
# test/Tomato_Bacterial_spot/ee328e30-524c-4bcd-86f2-e9facfa6c5ae___GCREC_Bact.Sp 6002_leaf.png → 9.51%
# test/Tomato_Bacterial_spot/eeae17c8-445e-4116-8329-48397093073a___GCREC_Bact.Sp 3459_leaf.png → 4.75%
# test/Tomato_Bacterial_spot/eed063ad-2337-413d-95be-3598f7a15942___GCREC_Bact.Sp 5663_leaf.png → 4.59%
# test/Tomato_Bacterial_spot/f0256cb3-6072-453f-9230-2ab16c2db646___GCREC_Bact.Sp 6303_leaf.png → 12.56%
# test/Tomato_Bacterial_spot/f073c2a6-ac26-49d4-a76d-049abbdb2cfa___GCREC_Bact.Sp 3067_leaf.png → 10.76%
# test/Tomato_Bacterial_spot/f295d002-ba3b-45f4-ad4d-44ecf10afbf7___GCREC_Bact.Sp 5820_leaf.png → 8.62%
# test/Tomato_Bacterial_spot/f2be2ee6-efba-4854-89b1-32eb0e7e6974___GCREC_Bact.Sp 5993_leaf.png → 5.98%
# test/Tomato_Bacterial_spot/f2f807a2-8777-4a1f-a33b-d1826d9d36c8___GCREC_Bact.Sp 3786_leaf.png → 7.25%
# test/Tomato_Bacterial_spot/f47f66f7-19c1-46d2-8dd1-24ad16f0b670___UF.GRC_BS_Lab Leaf 0225_leaf.png → 12.64%
# test/Tomato_Bacterial_spot/f5d65946-2c64-4de0-8769-ec32c6d8ee0c___GCREC_Bact.Sp 6168_leaf.png → 8.24%
# test/Tomato_Bacterial_spot/f675726b-1569-4147-9af2-23ac17a555ec___GCREC_Bact.Sp 3150_leaf.png → 6.71%
# test/Tomato_Bacterial_spot/f715c7e4-8b89-4eda-b020-adcf49e910f0___GCREC_Bact.Sp 6315_leaf.png → 12.21%
# test/Tomato_Bacterial_spot/f790b5c0-15b7-4adc-916f-fd4add9a72dd___GCREC_Bact.Sp 3128_leaf.png → 6.41%
# test/Tomato_Bacterial_spot/f7b71d93-0c1e-4bfe-a00c-004ad1cd2158___GCREC_Bact.Sp 6298_leaf.png → 6.85%
# test/Tomato_Bacterial_spot/f82504ab-2205-4b5e-968f-225eff5b22fb___GCREC_Bact.Sp 3705_leaf.png → 3.78%
# test/Tomato_Bacterial_spot/f9ca8392-73cf-4045-96f4-5fe481418df1___GCREC_Bact.Sp 3165_leaf.png → 11.95%
# test/Tomato_Bacterial_spot/fa3f0b33-f0a0-4625-b7c9-135bea953d91___GCREC_Bact.Sp 6028_leaf.png → 13.89%
# test/Tomato_Bacterial_spot/face0e7f-6173-456e-9ee5-973aedb41c3b___GCREC_Bact.Sp 3493_leaf.png → 8.39%
# test/Tomato_Bacterial_spot/fae0cb2c-797d-49d8-820a-52ccd350f8fd___UF.GRC_BS_Lab Leaf 0394_leaf.png → 17.52%
# test/Tomato_Bacterial_spot/fbae79e4-5907-44e2-b249-68e0643f1a21___UF.GRC_BS_Lab Leaf 0330_leaf.png → 13.43%
# test/Tomato_Bacterial_spot/fc48610a-675f-4fdf-998d-5d877c909550___GCREC_Bact.Sp 2959_leaf.png → 14.79%
# test/Tomato_Bacterial_spot/fdd0012a-bf6a-4c3f-83b7-8e11a58f69d4___GCREC_Bact.Sp 6285_leaf.png → 17.29%
# test/Tomato_Early_blight/0012b9d2-2130-4a06-a834-b1f3af34f57e___RS_Erly.B 8389_leaf.png → 11.75%
# test/Tomato_Early_blight/0034a551-9512-44e5-ba6c-827f85ecc688___RS_Erly.B 9432_leaf.png → 20.25%
# test/Tomato_Early_blight/0114f7b3-7f56-4bef-aa47-7a82da142d4b___RS_Erly.B 7437_leaf.png → 9.84%
# test/Tomato_Early_blight/0208ed52-1b28-4c9c-88e3-4667581e1109___RS_Erly.B 7829_leaf.png → 13.39%
# test/Tomato_Early_blight/0401adc0-0998-4d8e-90de-4eae8caf4248___RS_Erly.B 8446_leaf.png → 8.32%
# test/Tomato_Early_blight/04747279-48b2-4ce1-932b-e511424beb6b___RS_Erly.B 8240_leaf.png → 17.08%
# test/Tomato_Early_blight/06d0298e-18e5-4bf5-8d33-8feef6600f15___RS_Erly.B 7573_leaf.png → 13.47%
# test/Tomato_Early_blight/070679a9-27e1-4e6e-8072-29f3750d525b___RS_Erly.B 6439_leaf.png → 40.84%
# test/Tomato_Early_blight/08fe6531-bb66-4e0a-98b3-4b86a794f9f9___RS_Erly.B 7483_leaf.png → 7.71%
# test/Tomato_Early_blight/0982d864-182e-4d36-959a-dcc67d85d9e6___RS_Erly.B 9481_leaf.png → 21.56%
# test/Tomato_Early_blight/0bed4d68-b82c-4e96-bbfe-e0fc10df01aa___RS_Erly.B 8301_leaf.png → 9.16%
# test/Tomato_Early_blight/0c221e01-a85e-4794-b45b-3a91e349a8d2___RS_Erly.B 6425_leaf.png → 28.66%
# test/Tomato_Early_blight/10a46a0b-debe-49f9-8562-c7c81855160e___RS_Erly.B 6339_leaf.png → 13.73%
# test/Tomato_Early_blight/121b3f84-70ed-4d1c-882c-d3204e2af046___RS_Erly.B 8421_leaf.png → 22.73%
# test/Tomato_Early_blight/1742dfdd-c687-46ff-b958-34194feb68e4___RS_Erly.B 7453_leaf.png → 9.27%
# test/Tomato_Early_blight/17a09abf-ee69-4d46-ac80-f8608d799b19___RS_Erly.B 7451_leaf.png → 7.83%
# test/Tomato_Early_blight/18d8f15c-4948-4506-ae09-54169f95cf36___RS_Erly.B 7496_leaf.png → 28.24%
# test/Tomato_Early_blight/197fa869-c124-436e-b3cd-bced95f52a8e___RS_Erly.B 7834_leaf.png → 7.82%
# test/Tomato_Early_blight/1b4a2ad5-057d-4fac-9188-648edbe49751___RS_Erly.B 7767_leaf.png → 5.94%
# test/Tomato_Early_blight/1ba9a636-a673-45bc-b515-4fe6848f271e___RS_Erly.B 9605_leaf.png → 29.39%
# test/Tomato_Early_blight/1c057b5e-9ad7-4d51-b407-c60637005a13___RS_Erly.B 7594_leaf.png → 7.22%
# test/Tomato_Early_blight/1cebc4a1-5fb6-4168-8e18-e2973ef6d18f___RS_Erly.B 9552_leaf.png → 18.43%
# test/Tomato_Early_blight/1dad664e-ec73-474e-aaf9-a832ca212e3f___RS_Erly.B 7533_leaf.png → 22.12%
# test/Tomato_Early_blight/1f4c9f8a-5672-4e47-84dd-55f85f953174___RS_Erly.B 7582_leaf.png → 12.61%
# test/Tomato_Early_blight/203d84bc-4acc-4cad-b4f9-f659ae641876___RS_Erly.B 7615_leaf.png → 19.05%
# test/Tomato_Early_blight/2165f0a3-1265-491d-ad8a-e53102a87e9b___RS_Erly.B 9376_leaf.png → 26.39%
# test/Tomato_Early_blight/22742bf8-7e7f-41cc-bf74-5fe80d6cf0cd___RS_Erly.B 6370_leaf.png → 17.15%
# test/Tomato_Early_blight/22faea13-4b3e-4d87-b80c-379755a7b747___RS_Erly.B 7852_leaf.png → 11.14%
# test/Tomato_Early_blight/2419fd79-cda0-4ba4-be14-31c92a2e91dd___RS_Erly.B 8255_leaf.png → 14.42%
# test/Tomato_Early_blight/248f220e-56ac-43f1-8f17-641ed4637138___RS_Erly.B 7802_leaf.png → 15.62%
# test/Tomato_Early_blight/24f5a397-b5ac-451c-b979-28ee2bb056e6___RS_Erly.B 7795_leaf.png → 9.76%
# test/Tomato_Early_blight/25281e43-2651-423f-8e7e-d354185ccd28___RS_Erly.B 7809_leaf.png → 13.60%
# test/Tomato_Early_blight/25430871-a740-4dd8-a836-bf2d52eb233b___RS_Erly.B 6420_leaf.png → 28.45%
# test/Tomato_Early_blight/26e2e7aa-800c-421b-92e8-3e20c5f5757e___RS_Erly.B 7656_leaf.png → 32.42%
# test/Tomato_Early_blight/27ba7432-8547-436c-9b97-adf3cbe15575___RS_Erly.B 7544_leaf.png → 14.35%
# test/Tomato_Early_blight/29345423-647e-4e1b-81f4-16d8cfc0e137___RS_Erly.B 7422_leaf.png → 17.01%
# test/Tomato_Early_blight/2b5bebdd-3af4-41ca-b206-efc1a141e71d___RS_Erly.B 6363_leaf.png → 38.36%
# test/Tomato_Early_blight/2c9fda20-f414-4aaa-8798-faf6bc38f014___RS_Erly.B 6491_leaf.png → 16.38%
# test/Tomato_Early_blight/2d3d1221-2f62-43ad-8256-b560c1872934___RS_Erly.B 7465_leaf.png → 20.59%
# test/Tomato_Early_blight/30e6be40-743f-49c1-a736-e279d53ffdd7___RS_Erly.B 7862_leaf.png → 18.17%
# test/Tomato_Early_blight/3198b703-d5d5-46e9-9b8f-399d5531b5c4___RS_Erly.B 8364_leaf.png → 20.29%
# test/Tomato_Early_blight/3253ff4e-90ab-475a-89d2-f99875c53367___RS_Erly.B 8356_leaf.png → 18.35%
# test/Tomato_Early_blight/3592b22c-09cd-4005-97c4-cdd11318cce0___RS_Erly.B 9391_leaf.png → 11.55%
# test/Tomato_Early_blight/389a93c4-2ea1-4df5-94c6-01ea8ad856db___RS_Erly.B 7720_leaf.png → 11.65%
# test/Tomato_Early_blight/3fa32b26-e7bb-493e-b7c2-c40e3f3df380___RS_Erly.B 9546_leaf.png → 12.90%
# test/Tomato_Early_blight/427229e9-359c-49c5-8dfd-b721a3802899___RS_Erly.B 7861_leaf.png → 21.84%
# test/Tomato_Early_blight/4490b039-427d-414c-836d-a1fda6c1ad49___RS_Erly.B 8369_leaf.png → 12.09%
# test/Tomato_Early_blight/45a51377-1fd4-45f3-bfdb-02d9d0953ab2___RS_Erly.B 9471_leaf.png → 18.92%
# test/Tomato_Early_blight/4cbe4896-66b5-4834-8eb7-5baf49ed2f7d___RS_Erly.B 8354_leaf.png → 21.26%
# test/Tomato_Early_blight/4e8e92ba-46f4-4e49-850b-71019f6c8640___RS_Erly.B 6346_leaf.png → 22.16%
# test/Tomato_Early_blight/506f85e7-6f27-40e2-bb9c-5ddb6f35a787___RS_Erly.B 8406_leaf.png → 22.17%
# test/Tomato_Early_blight/50cd977c-9fa8-4ff2-9a82-9d848f0a8972___RS_Erly.B 7683_leaf.png → 2.66%
# test/Tomato_Early_blight/511fb1ba-bef6-4144-9e05-461a66022cba___RS_Erly.B 8435_leaf.png → 18.74%
# test/Tomato_Early_blight/51f589f7-d843-4d5d-8c5a-385951f58865___RS_Erly.B 9424_leaf.png → 21.92%
# test/Tomato_Early_blight/5339898b-4bf4-4ee0-b69c-eac14c202a69___RS_Erly.B 9430_leaf.png → 19.15%
# test/Tomato_Early_blight/533debcd-c993-4c11-8515-9ec280cdc023___RS_Erly.B 7389_leaf.png → 19.14%
# test/Tomato_Early_blight/56e77ea3-5b58-409c-991d-c6d1e3740f65___RS_Erly.B 7358_leaf.png → 13.22%
# test/Tomato_Early_blight/58268d35-a896-406d-9686-5f2f2b9a5b10___RS_Erly.B 7433_leaf.png → 13.44%
# test/Tomato_Early_blight/59cbcb57-16e3-4e35-a1d6-8672678c9d8d___RS_Erly.B 6489_leaf.png → 33.60%
# test/Tomato_Early_blight/5ac54e63-40a4-4651-a900-fd3ab4d32bae___RS_Erly.B 7727_leaf.png → 11.51%
# test/Tomato_Early_blight/5c8ced5b-fa5c-41d4-8ad9-a3c7c4891355___RS_Erly.B 6350_leaf.png → 20.88%
# test/Tomato_Early_blight/5d0f4647-6f88-4c84-bacf-d6bc4d469c4d___RS_Erly.B 8411_leaf.png → 19.25%
# test/Tomato_Early_blight/5d45c117-439e-454a-bc77-93a27ce98761___RS_Erly.B 7546_leaf.png → 26.57%
# test/Tomato_Early_blight/5d998134-578b-481e-9b88-df0134eb567b___RS_Erly.B 7626_leaf.png → 16.10%
#
# Saved all-splits results to 'results_with_infected_area_all_splits.csv'
